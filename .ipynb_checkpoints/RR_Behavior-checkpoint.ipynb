# %%
import pandas as pd
import re
import numpy as np

# %%
filePath = '/Users/lexizhou/Desktop/RR_bonsai_events_TS.csv'

# %%
events = pd.read_csv(filePath)
events = events.rename(columns={'9':"event_code", events.columns[0]: 'event', '246.7670912': 'timestamp'})
if len(events.columns) > 3:
    events = events.drop(events.columns[3], axis=1)
if 'Unnamed: 3' in events.columns:
    events = events.drop(columns=['Unnamed: 3'])
events['event'] = events['event'].str.replace('[^\w\s]','')

event_code_dic = events.groupby(['event', 'event_code']).size()
event_code_dic = event_code_dic.to_frame().reset_index().set_index('event_code')
event_code_dict = event_code_dic.to_dict()['event']

events_list = events.values.tolist()
events_list
# Out:
# [['Mouse in offer zone 1', 246.80968959999998, 10],
#  ['R1 100 offer', 247.0, 20],
#  ['Enter R1', 247.0, 11],
#  ['Quit R1', 252.716992, 13],
#  ['Mouse in hall 2', 253.3837312, 21],
#  ['Mouse in offer zone 2', 253.5054336, 22],
#  ['R 2 0 offer', 253.51754240000002, 29],
#  ['Enter R2', 255.90618880000002, 23],
#  ['R 2 noreward tone', 262.972096, 27],
#  ['Quit R2', 363.43120639999995, 25],
#  ['Mouse in hall 3', 363.49783039999994, 33],
#  ['Mouse in offer zone 3', 365.9704832, 34],
#  ['R3 0 offer', 365.98688, 41],
#  ['Enter R3', 367.67199999999997, 35],
#  ['R3 noreward tone', 374.7444992, 39],
#  ['Quit R3', 414.3253376, 37],
#  ['Mouse in hall 4', 414.49186560000004, 45],
#  ['Mouse in offer zone 4', 414.62776319999995, 46],
#  ['R4 0 offer', 414.6416512, 53],
#  ['Enter R4', 416.5275648, 47],
#  ['R4 noreward tone', 423.6059648, 51],
#  ['Quit R4', 426.1719552, 49],
#  ['Mouse in hall 1', 426.6690688, 9],
#  ['Mouse in hall 1', 428.77493760000004, 9],
#  ['Mouse in offer zone 1', 429.882496, 10],
#  ['R1 20 offer', 429.885568, 18],
#  ['Enter R1', 431.483712, 11],
#  ['R1 noreward tone', 436.53208319999993, 15],
#  ['Quit R1', 520.4531968, 13],
#  ['Mouse in hall 2', 520.5879808, 21],
#  ['Mouse in offer zone 2', 520.909952, 22],
#  ['R2 20 offer', 520.9168639999999, 30],
#  ['Enter R2', 522.8465536, 23],
#  ['R 2 noreward tone', 527.8572416000001, 27],
#  ['Quit R2', 611.2837503999999, 25],
#  ['Mouse in hall 2', 613.4583167999999, 21],
#  ['Enter R1', 614.0576512, 11],
#  ['Quit R1', 623.3758207999999, 13],
#  ['Mouse in hall 1', 624.7597440000001, 9],
#  ['Enter R4', 627.3678976, 47],
#  ['Quit R4', 639.2768127999999, 49],
#  ['Enter R4', 639.3104128, 47],
#  ['Quit R4', 639.3435776, 49],
#  ['Mouse in hall 4', 642.2147456, 45],
#  ['Enter R3', 642.6813952, 35],
#  ['Quit R3', 654.0993152000001, 37],
#  ['Mouse in hall 3', 656.3304063999999, 33],
#  ['Mouse in offer zone 2', 656.4654336, 22],
#  ['Enter R2', 656.6965376, 23],
#  ['Quit R2', 665.4728064, 25],
#  ['Enter R2', 665.538944, 23],
#  ['Quit R2', 665.7117184, 25],
#  ['Enter R2', 665.7748352000001, 23],
#  ['Quit R2', 665.9111807999999, 25],
#  ['Enter R2', 665.9761152000001, 23],
#  ['Quit R2', 666.0420352000001, 25],
#  ['Enter R2', 666.142144, 23],
#  ['Quit R2', 667.0433152, 25],
#  ['Enter R2', 667.0756992, 23],
#  ['Quit R2', 667.1152256, 25],
#  ['Enter R2', 667.1460736, 23],
#  ['Quit R2', 667.2456063999999, 25],
#  ['Enter R2', 667.2795136, 23],
#  ['Quit R2', 667.84128, 25],
#  ['Enter R2', 667.9780607999999, 23],
#  ['Quit R2', 668.0103936, 25],
#  ['Enter R2', 668.0452864, 23],
#  ['Quit R2', 668.0770944, 25],
#  ['Enter R2', 668.1437440000001, 23],
#  ['Quit R2', 668.2450816, 25],
#  ['Enter R2', 668.2792576, 23],
#  ['Quit R2', 668.3108096, 25],
#  ['Enter R2', 668.34528, 23],
#  ['Quit R2', 668.644288, 25],
#  ['Enter R2', 668.6787456000001, 23],
#  ['Quit R2', 669.08064, 25],
#  ['Enter R2', 669.1454976, 23],
#  ['Quit R2', 669.41216, 25],
#  ['Enter R2', 669.4464512, 23],
#  ['Quit R2', 673.0809343999999, 25],
#  ['Enter R2', 673.1153408, 23],
#  ['Quit R2', 678.725184, 25],
#  ['Enter R2', 678.7564160000001, 23],
#  ['Quit R2', 678.9876992000001, 25],
#  ['Enter R2', 679.0216832, 23],
#  ['Quit R2', 679.0900864, 25],
#  ['Enter R2', 679.5922816000001, 23],
#  ['Quit R2', 680.6925056, 25],
#  ['Enter R2', 680.8262272000001, 23],
#  ['Quit R2', 680.9229184, 25],
#  ['Enter R2', 680.9564416000001, 23],
#  ['Quit R2', 681.426304, 25],
#  ['Enter R2', 681.4651136, 23],
#  ['Quit R2', 683.564416, 25],
#  ['Enter R2', 683.8607616, 23],
#  ['Quit R2', 683.9267072, 25],
#  ['Enter R2', 684.0329088, 23],
#  ['Quit R2', 684.1950336, 25],
#  ['Enter R2', 684.2268928, 23],
#  ['Quit R2', 684.3295744, 25],
#  ['Enter R2', 684.6316544, 23],
#  ['Quit R2', 685.0705664, 25],
#  ['Enter R2', 685.0970368, 23],
#  ['Quit R2', 685.1969024, 25],
#  ['Enter R2', 685.2625024, 23],
#  ['Quit R2', 685.3621504, 25],
#  ['Enter R2', 685.431616, 23],
#  ['Quit R2', 685.7313408, 25],
#  ['Enter R2', 685.7953536, 23],
#  ['Quit R2', 685.8965504, 25],
#  ['Enter R2', 685.9306112, 23],
#  ['Quit R2', 685.9634176, 25],
#  ['Enter R2', 685.9958528, 23],
#  ['Quit R2', 686.0297727999999, 25],
#  ['Enter R2', 686.0630656000001, 23],
#  ['Quit R2', 688.0013312000001, 25],
#  ['Mouse in hall 2', 689.4829952, 21],
#  ['Mouse in offer zone 1', 689.7120768, 10],
#  ['Enter R1', 690.0776448, 11],
#  ['Quit R1', 699.3586944, 13],
#  ['Mouse in hall 1', 702.1494912, 9],
#  ['Mouse in offer zone 4', 702.51648, 46],
#  ['Enter R4', 703.4201856000001, 47],
#  ['Quit R4', 724.7102719999999, 49],
#  ['Mouse in hall 4', 726.178368, 45],
#  ['Mouse in offer zone 3', 726.3472256, 34],
#  ['Enter R3', 726.5449087999999, 35],
#  ['Quit R3', 740.8616704, 37],
#  ['Mouse in hall 3', 742.0613503999999, 33],
#  ['Mouse in offer zone 2', 742.1940096, 22],
#  ['Enter R2', 742.426944, 23],
#  ['Quit R2', 821.9181312000001, 25],
#  ['Mouse in hall 3', 821.9850624, 33],
#  ['Mouse in offer zone 3', 822.2872064, 34],
#  ['R3 0 offer', 822.2876032, 41],
#  ['Enter R3', 823.1877632000001, 35],
#  ['R3 noreward tone', 830.1908864, 39],
#  ['Quit R3', 866.8420480000001, 37],
#  ['Mouse in hall 4', 866.9731968, 45],
#  ['Mouse in offer zone 4', 867.1009024, 46],
#  ['R4 0 offer', 867.1013376, 53],
#  ['Enter R4', 867.9707007999999, 47],
#  ['Quit R4', 873.4437119999999, 49],
#  ['Mouse in hall 1', 873.6415104, 9],
#  ['Mouse in offer zone 1', 873.854528, 10],
#  ['R1 100 offer', 873.8553088, 20],
#  ['Enter R1', 874.9876992000001, 11],
#  ['Servo 1 open', 875.9893504, 1],
#  ['R1 reward taken', 880.270912, 16],
#  ['Quit R1', 933.6880384, 13],
#  ['Mouse in hall 2', 937.793728, 21],
#  ['Mouse in offer zone 2', 937.9202687999999, 22],
#  ['R2 20 offer', 937.9208960000001, 30],
#  ['Enter R2', 938.4842495999999, 23],
#  ['Servo 2 open', 943.49952, 3],
#  ['R2 reward taken', 948.4028927999999, 28],
#  ['Quit R2', 990.3426816, 25],
#  ['Mouse in hall 3', 990.9499392000001, 33],
#  ['Mouse in offer zone 3', 991.2134912, 34],
#  ['R3 80 offer', 991.2164223999999, 43],
#  ['Enter R3', 991.9800704, 35],
#  ['Servo 3 open', 994.9948800000001, 5],
#  ['R3 reward taken', 1001.135411, 40],
#  ['Quit R3', 1027.6924800000002, 37],
#  ['Mouse in hall 4', 1027.854669, 45],
#  ['Mouse in offer zone 4', 1028.149517, 46],
#  ['R4 80 offer', 1028.151987, 55],
#  ['Enter R4', 1029.1205380000001, 47],
#  ['Servo 4 open', 1032.1372800000001, 7],
#  ['R4 reward taken', 1033.889638, 52],
#  ['Quit R4', 1050.808909, 49],
#  ['Mouse in hall 1', 1050.977306, 9],
#  ['Mouse in offer zone 1', 1051.193626, 10],
#  ['R1 80 offer', 1051.1954560000001, 19],
#  ['Enter R1', 1052.155674, 11],
#  ['R1 noreward tone', 1055.169613, 15],
#  ['Quit R1', 1062.206758, 13],
#  ['Mouse in hall 2', 1062.337626, 21],
#  ['Mouse in offer zone 2', 1062.431411, 22],
#  ['R2 80 offer', 1062.4321539999999, 31],
#  ['Enter R2', 1063.3292800000002, 23],
#  ['Servo 2 open', 1066.34473, 3],
#  ['R2 reward taken', 1078.512, 28],
#  ['Quit R2', 1100.635149, 25],
#  ['Mouse in hall 3', 1100.738419, 33],
#  ['Mouse in offer zone 3', 1100.877235, 34],
#  ['R3 0 offer', 1100.878042, 41],
#  ['Enter R3', 1101.542912, 35],
#  ['Quit R3', 1104.655706, 37],
#  ['Mouse in hall 4', 1104.8121859999999, 45],
#  ['Mouse in offer zone 4', 1104.903706, 46],
#  ['R4 20 offer', 1104.904896, 54],
#  ['Enter R4', 1105.70391, 47],
#  ['R4 noreward tone', 1110.7167359999999, 51],
#  ['Quit R4', 1112.280896, 49],
#  ['Mouse in hall 1', 1112.347533, 9],
#  ['Mouse in offer zone 1', 1112.661453, 10],
#  ['R1 20 offer', 1112.6624259999999, 18],
#  ['Enter R1', 1113.691917, 11],
#  ['R1 noreward tone', 1118.708736, 15],
#  ['Quit R1', 1127.743373, 13],
#  ['Mouse in hall 2', 1127.911654, 21],
#  ['Mouse in offer zone 2', 1128.036646, 22],
#  ['R2 100 offer', 1128.037325, 32],
#  ['Enter R2', 1128.906714, 23],
#  ['Servo 2 open', 1129.9171199999998, 3],
#  ['R2 reward taken', 1139.674227, 28],
#  ['Quit R2', 1167.345741, 25],
#  ['Enter R2', 1168.27872, 23],
#  ['Quit R2', 1169.451546, 25],
#  ['Enter R2', 1173.317683, 23],
#  ['Quit R2', 1175.092198, 25],
#  ['Mouse in hall 2', 1181.137242, 21],
#  ['Enter R1', 1181.606182, 11],
#  ['Quit R1', 1183.604493, 13],
#  ['Mouse in hall 1', 1188.597965, 9],
#  ['Enter R4', 1189.398528, 47],
#  ['Mouse in hall 1', 1192.471821, 9],
#  ['Mouse in hall 1', 1192.670797, 9],
#  ['Quit R4', 1192.9046779999999, 49],
#  ['Mouse in hall 1', 1192.936077, 9],
#  ['Mouse in hall 4', 1196.715251, 45],
#  ['Enter R3', 1197.048486, 35],
#  ['Quit R3', 1207.659802, 37],
#  ['Mouse in hall 3', 1210.296179, 33],
#  ['Mouse in offer zone 2', 1211.533056, 22],
#  ['Enter R2', 1213.063398, 23],
#  ['Quit R2', 1242.629901, 25],
#  ['Mouse in hall 2', 1243.7067140000001, 21],
#  ['Mouse in offer zone 1', 1243.907354, 10],
#  ['Enter R1', 1244.374362, 11],
#  ['Quit R1', 1257.1884929999999, 13],
#  ['Mouse in hall 1', 1260.479309, 9],
#  ['Mouse in offer zone 4', 1260.84681, 46],
#  ['Enter R4', 1261.179776, 47],
#  ['Mouse in hall 1', 1274.465037, 9],
#  ['Quit R4', 1274.83241, 49],
#  ['Mouse in hall 1', 1275.064653, 9],
#  ['Mouse in offer zone 1', 1275.843136, 10],
#  ['Enter R1', 1277.078234, 11],
#  ['Quit R1', 1279.38048, 13],
#  ['Mouse in hall 2', 1279.447334, 21],
#  ['Mouse in offer zone 2', 1279.544384, 22],
#  ['Enter R2', 1280.3413890000002, 23],
#  ['Quit R2', 1287.322483, 25],
#  ['Enter R2', 1291.359718, 23],
#  ['Quit R2', 1291.391667, 25],
#  ['Enter R2', 1291.4231550000002, 23],
#  ['Quit R2', 1291.4582269999999, 25],
#  ['Enter R2', 1291.5592960000001, 23],
#  ['Quit R2', 1295.523878, 25],
#  ['Enter R2', 1300.76791, 23],
#  ['Quit R2', 1312.7794689999998, 25],
#  ['Enter R2', 1312.883149, 23],
#  ['Quit R2', 1312.949632, 25],
#  ['Enter R2', 1321.424307, 23],
#  ['Quit R2', 1321.754394, 25],
#  ['Enter R2', 1321.787699, 23],
#  ['Quit R2', 1321.821862, 25],
#  ['Enter R2', 1322.287949, 23],
#  ['Quit R2', 1329.629146, 25],
#  ['Mouse in hall 3', 1329.83145, 33],
#  ['Mouse in offer zone 3', 1330.033702, 34],
#  ['R3 80 offer', 1330.034253, 43],
#  ['Enter R3', 1330.8345980000001, 35],
#  ['Servo 3 open', 1333.8369539999999, 5],
#  ['R3 reward taken', 1335.8573310000002, 40],
#  ['Quit R3', 1353.592294, 37],
#  ['Mouse in hall 4', 1353.726029, 45],
#  ['Mouse in offer zone 4', 1353.885491, 46],
#  ['R4 20 offer', 1353.885888, 54],
#  ['Enter R4', 1355.020928, 47],
#  ['R4 noreward tone', 1360.036749, 51],
#  ['Quit R4', 1372.472448, 49],
#  ['Mouse in hall 1', 1372.639027, 9],
#  ['Mouse in offer zone 1', 1372.888192, 10],
#  ['R1 0 offer', 1372.888678, 17],
#  ['Mouse in hall 1', 1373.2077179999999, 9],
#  ['Mouse in hall 2', 1373.9597310000001, 21],
#  ['Mouse in offer zone 2', 1374.1150460000001, 22],
#  ['R2 80 offer', 1374.115584, 31],
#  ['Enter R2', 1374.9806720000001, 23],
#  ['Servo 2 open', 1377.991066, 3],
#  ['R2 reward taken', 1379.536947, 28],
#  ['Quit R2', 1397.940467, 25],
#  ['Mouse in hall 2', 1400.553933, 21],
#  ['Mouse in offer zone 1', 1401.020544, 10],
#  ['Enter R1', 1401.387802, 11],
#  ['Quit R1', 1418.007232, 13],
#  ['Mouse in hall 1', 1421.463565, 9],
#  ['Enter R4', 1427.735514, 47],
#  ['Quit R4', 1434.71081, 49],
#  ['Mouse in hall 4', 1436.923866, 45],
#  ['Enter R3', 1437.927142, 35],
#  ['Quit R3', 1445.6669570000001, 37],
#  ['Mouse in hall 4', 1445.802829, 45],
#  ['Mouse in offer zone 4', 1445.927258, 46],
#  ['Enter R4', 1446.995584, 47],
#  ['Quit R4', 1452.096742, 49],
#  ['Mouse in hall 1', 1452.1963779999999, 9],
#  ['Mouse in offer zone 1', 1452.544128, 10],
#  ['Enter R1', 1453.6479869999998, 11],
#  ['Quit R1', 1455.914419, 13],
#  ['Mouse in hall 2', 1456.014643, 21],
#  ['Mouse in offer zone 2', 1456.1069439999999, 22],
#  ['Enter R2', 1457.0444929999999, 23],
#  ['Quit R2', 1465.719117, 25],
#  ['Enter R2', 1465.786675, 23],
#  ['Quit R2', 1465.85111, 25],
#  ['Enter R2', 1540.4719619999998, 23],
#  ['Quit R2', 1620.565926, 25],
#  ['Mouse in hall 3', 1620.6308609999999, 33],
#  ['Mouse in offer zone 3', 1621.131763, 34],
#  ['R3 80 offer', 1621.132198, 43],
#  ['Enter R3', 1622.39881, 35],
#  ['R3 noreward tone', 1625.4012539999999, 39],
#  ['Quit R3', 1637.916902, 37],
#  ['Mouse in hall 4', 1638.08329, 45],
#  ['Mouse in offer zone 4', 1638.2737539999998, 46],
#  ['R4 80 offer', 1638.274202, 55],
#  ['Enter R4', 1639.245069, 47],
#  ['R4 noreward tone', 1642.262093, 51],
#  ['Quit R4', 1653.6913279999999, 49],
#  ['Mouse in hall 1', 1653.75703, 9],
#  ['Mouse in offer zone 1', 1654.0066689999999, 10],
#  ['R1 80 offer', 1654.007885, 19],
#  ['Enter R1', 1655.141018, 11],
#  ['Servo 1 open', 1658.157542, 1],
#  ['R1 reward taken', 1659.73353, 16],
#  ['Quit R1', 1680.236109, 13],
#  ['Enter R1', 1681.6376059999998, 11],
#  ['Quit R1', 1686.245581, 13],
#  ['Enter R1', 1686.5099010000001, 11],
#  ['Quit R1', 1686.6790399999998, 13],
#  ['Mouse in hall 2', 1687.8125949999999, 21],
#  ['Mouse in offer zone 2', 1688.0081149999999, 22],
#  ['R 2 0 offer', 1688.011328, 29],
#  ['Enter R2', 1689.3067260000003, 23],
#  ['R 2 noreward tone', 1696.3225730000001, 27],
#  ['Quit R2', 1703.7894019999999, 25],
#  ['Enter R2', 1709.232883, 23],
#  ['Quit R2', 1715.969677, 25],
#  ['Mouse in hall 3', 1716.537242, 33],
#  ['Mouse in offer zone 3', 1716.7071230000001, 34],
#  ['R3 0 offer', 1716.707661, 41],
#  ['Enter R3', 1717.580659, 35],
#  ['R3 noreward tone', 1724.598387, 39],
#  ['Quit R3', 1725.621478, 37],
#  ['Mouse in hall 4', 1725.824614, 45],
#  ['Mouse in offer zone 4', 1725.939098, 46],
#  ['R4 0 offer', 1725.9394690000001, 53],
#  ['Enter R4', 1727.107507, 47],
#  ['R4 noreward tone', 1734.1246850000002, 51],
#  ['Quit R4', 1739.189504, 49],
#  ['Mouse in hall 4', 1741.236787, 45],
#  ['Enter R3', 1741.7026050000002, 35],
#  ['Quit R3', 1756.3522050000001, 37],
#  ['Mouse in hall 3', 1759.187789, 33],
#  ['Enter R2', 1759.6888059999999, 23],
#  ['Quit R2', 1767.462886, 25],
#  ['Enter R2', 1767.5631489999998, 23],
#  ['Quit R2', 1767.597312, 25],
#  ['Enter R2', 1767.629197, 23],
#  ['Quit R2', 1780.345306, 25],
#  ['Mouse in hall 2', 1785.9579780000001, 21],
#  ['Enter R1', 1787.0588670000002, 11],
#  ['Quit R1', 1809.1520899999998, 13],
#  ['Mouse in hall 1', 1810.9688190000002, 9],
#  ['Mouse in offer zone 4', 1811.2041980000001, 46],
#  ['Enter R4', 1811.5030780000002, 47],
#  ['Quit R4', 1830.1991679999999, 49],
#  ['Mouse in hall 1', 1830.892813, 9],
#  ['Mouse in hall 1', 1830.9577980000001, 9],
#  ['Mouse in hall 1', 1831.126592, 9],
#  ['Mouse in hall 1', 1831.3655420000002, 9],
#  ['Mouse in hall 1', 1831.461402, 9],
#  ['Mouse in hall 1', 1832.028186, 9],
#  ['Mouse in hall 1', 1834.699366, 9],
#  ['Mouse in hall 4', 1837.7450620000002, 45],
#  ['Mouse in offer zone 3', 1838.078349, 34],
#  ['Enter R3', 1838.849011, 35],
#  ['Quit R3', 1847.8892420000002, 37],
#  ['Mouse in hall 3', 1849.8900219999998, 33],
#  ['Mouse in offer zone 2', 1850.189914, 22],
#  ['Mouse in hall 3', 1850.556237, 33],
#  ['Enter R2', 1850.656346, 23],
#  ['Quit R2', 1874.7849469999999, 25],
#  ['Mouse in hall 3', 1876.6527620000002, 33],
#  ['Mouse in offer zone 3', 1881.730816, 34],
#  ['Mouse in hall 3', 1882.8944379999998, 33],
#  ['Enter R3', 1886.5679739999998, 35],
#  ['Quit R3', 1890.975885, 37],
#  ['Mouse in hall 4', 1891.2395010000002, 45],
#  ['Mouse in offer zone 4', 1891.561882, 46],
#  ['Enter R4', 1892.795968, 47],
#  ['Quit R4', 1898.6044160000001, 49],
#  ['Mouse in hall 1', 1898.6673920000003, 9],
#  ['Mouse in offer zone 1', 1898.855795, 10],
#  ['R1 0 offer', 1898.8563329999997, 17],
#  ['Enter R1', 1899.855757, 11],
#  ['Quit R1', 1901.9558530000002, 13],
#  ['Mouse in hall 2', 1902.0265219999999, 21],
#  ['Mouse in offer zone 2', 1902.116122, 22],
#  ['R 2 0 offer', 1902.11657, 29],
#  ['Enter R2', 1903.082995, 23],
#  ['R 2 noreward tone', 1910.0892030000002, 27],
#  ['Quit R2', 1912.561882, 25],
#  ['Mouse in hall 3', 1912.660314, 33],
#  ['Mouse in offer zone 3', 1912.83072, 34],
#  ['R3 0 offer', 1912.831066, 41],
#  ['Enter R3', 1913.564365, 35],
#  ['Quit R3', 1917.4352379999998, 37],
#  ['Mouse in hall 4', 1917.637107, 45],
#  ['Mouse in offer zone 4', 1917.856602, 46],
#  ['R4 20 offer', 1917.857037, 54],
#  ['Enter R4', 1919.059776, 47],
#  ['R4 noreward tone', 1924.06455, 51],
#  ['Quit R4', 1929.2381699999999, 49],
#  ['Mouse in hall 1', 1929.303974, 9],
#  ['Mouse in offer zone 1', 1929.555968, 10],
#  ['R1 20 offer', 1929.556774, 18],
#  ['Enter R1', 1930.6932350000002, 11],
#  ['R1 noreward tone', 1935.705766, 15],
#  ['Quit R1', 1938.765197, 13],
#  ['Mouse in hall 2', 1938.8727039999999, 21],
#  ['Mouse in offer zone 2', 1939.0584829999998, 22],
#  ['R2 100 offer', 1939.058893, 32],
#  ['Enter R2', 1940.225536, 23],
#  ['Servo 2 open', 1941.2336899999998, 3],
#  ['R2 reward taken', 1942.537446, 28],
#  ['Quit R2', 1966.3593219999998, 25],
#  ['Enter R2', 1967.32425, 23],
#  ['Quit R2', 1997.3932539999998, 25],
#  ['Mouse in hall 3', 1997.4599039999998, 33],
#  ['Mouse in offer zone 3', 1997.631706, 34],
#  ['R3 20 offer', 1997.6324100000002, 42],
#  ['Enter R3', 1998.427904, 35],
#  ['R3 noreward tone', 2003.444019, 39],
#  ['Quit R3', 2004.100416, 37],
#  ['Mouse in hall 4', 2004.2672129999999, 45],
#  ['Mouse in offer zone 4', 2004.4546300000002, 46],
#  ['R4 20 offer', 2004.4549760000002, 54],
#  ['Enter R4', 2005.2259329999997, 47],
#  ['R4 noreward tone', 2010.24192, 51],
#  ['Mouse in hall 1', 2013.497907, 9],
#  ['Quit R4', 2014.6002429999999, 49],
#  ['Mouse in hall 4', 2016.9499010000002, 45],
#  ['Enter R3', 2017.5184129999998, 35],
#  ['Quit R3', 2024.692531, 37],
#  ['Mouse in hall 4', 2029.0628219999999, 45],
#  ['Mouse in offer zone 4', 2029.985254, 46],
#  ['Enter R4', 2031.7856379999998, 47],
#  ['Mouse in hall 1', 2039.460877, 9],
#  ['Mouse in hall 1', 2040.394816, 9],
#  ['Quit R4', 2040.829146, 49],
#  ['Mouse in hall 1', 2040.8624379999999, 9],
#  ['Mouse in offer zone 1', 2041.11913, 10],
#  ['R1 80 offer', 2041.1205120000002, 19],
#  ['Enter R1', 2042.215706, 11],
#  ['Servo 1 open', 2045.231014, 1],
#  ['R1 reward taken', 2050.501286, 16],
#  ['Quit R1', 2067.344141, 13],
#  ['Mouse in hall 2', 2067.54761, 21],
#  ['Mouse in offer zone 2', 2067.6736769999998, 22],
#  ['R2 80 offer', 2067.6743420000003, 31],
#  ['Enter R2', 2068.907136, 23],
#  ['Servo 2 open', 2071.922483, 3],
#  ['R2 reward taken', 2076.439398, 28],
#  ['Quit R2', 2130.109274, 25],
#  ['Mouse in hall 2', 2131.4848899999997, 21],
#  ['Enter R1', 2131.81856, 11],
#  ['Quit R1', 2137.461069, 13],
#  ['Mouse in hall 1', 2138.405338, 9],
#  ['Enter R4', 2138.844608, 47],
#  ['Quit R4', 2151.155738, 49],
#  ['Mouse in hall 4', 2151.807411, 45],
#  ['Enter R3', 2152.169459, 35],
#  ['Quit R3', 2155.9766019999997, 37],
#  ['Mouse in hall 4', 2156.376934, 45],
#  ['Mouse in offer zone 4', 2156.764032, 46],
#  ['Enter R4', 2157.831962, 47],
#  ['Mouse in hall 1', 2163.836787, 9],
#  ['Quit R4', 2163.836992, 49],
#  ['Mouse in offer zone 1', 2164.0211329999997, 10],
#  ['Enter R1', 2164.859085, 11],
#  ['Quit R1', 2168.926093, 13],
#  ['Mouse in hall 2', 2169.463142, 21],
#  ['Mouse in offer zone 2', 2170.3229309999997, 22],
#  ['Enter R2', 2171.989158, 23],
#  ['Quit R2', 2190.210381, 25],
#  ['Mouse in hall 2', 2191.42007, 21],
#  ['Enter R1', 2192.120973, 11],
#  ['Quit R1', 2192.252506, 13],
#  ['Enter R1', 2193.1624829999996, 11],
#  ['Quit R1', 2223.022912, 13],
#  ['Enter R1', 2223.089139, 11],
#  ['Quit R1', 2223.691763, 13],
#  ['Mouse in hall 2', 2223.9887870000002, 21],
#  ['Mouse in offer zone 2', 2224.2519039999997, 22],
#  ['Enter R2', 2225.617178, 23],
#  ['Quit R2', 2307.980365, 25],
#  ['Mouse in hall 2', 2311.055104, 21],
#  ['Enter R1', 2311.723123, 11],
#  ['Quit R1', 2324.836352, 13],
#  ['Mouse in hall 1', 2329.65929, 9],
#  ['Enter R4', 2331.162291, 47],
#  ['Quit R4', 2335.062054, 49],
#  ['Mouse in hall 4', 2337.248986, 45],
#  ['Enter R3', 2337.753741, 35],
#  ['Quit R3', 2346.126707, 37],
#  ['Mouse in hall 3', 2348.690483, 33],
#  ['Mouse in offer zone 2', 2349.024512, 22],
#  ['Enter R2', 2349.5921789999998, 23],
#  ['Quit R2', 2361.074189, 25],
#  ['Enter R2', 2369.3148539999997, 23],
#  ['Quit R2', 2369.783936, 25],
#  ['Enter R2', 2370.98505, 23],
#  ['Quit R2', 2397.285184, 25],
#  ['Mouse in hall 3', 2398.514099, 33],
#  ['Mouse in offer zone 3', 2398.8846719999997, 34],
#  ['R3 100 offer', 2398.8852100000004, 44],
#  ['Enter R3', 2399.98729, 35],
#  ['Servo 3 open', 2400.996787, 5],
#  ['R3 reward taken', 2402.2807420000004, 40],
#  ['Quit R3', 2416.40416, 37],
#  ['Mouse in hall 4', 2416.674202, 45],
#  ['Mouse in offer zone 4', 2416.9879170000004, 46],
#  ['R4 20 offer', 2416.9883010000003, 54],
#  ['Enter R4', 2417.8881920000003, 47],
#  ['R4 noreward tone', 2422.9022210000003, 51],
#  ['Mouse in hall 1', 2430.969638, 9],
#  ['Mouse in hall 1', 2431.1069820000002, 9],
#  ['Quit R4', 2431.107264, 49],
#  ['Mouse in hall 1', 2431.2056190000003, 9],
#  ['Mouse in offer zone 1', 2431.458765, 10],
#  ['R1 20 offer', 2431.459546, 18],
#  ['Enter R1', 2432.527885, 11],
#  ['R1 noreward tone', 2437.5311739999997, 15],
#  ['Quit R1', 2440.544218, 13],
#  ['Mouse in hall 2', 2440.637811, 21],
#  ['Mouse in offer zone 2', 2440.765798, 22],
#  ['R2 20 offer', 2440.767258, 30],
#  ['Enter R2', 2441.898982, 23],
#  ['R 2 noreward tone', 2446.916531, 27],
#  ['Quit R2', 2453.046131, 25],
#  ['Mouse in hall 3', 2453.145638, 33],
#  ['Mouse in offer zone 3', 2453.314982, 34],
#  ['R3 20 offer', 2453.315597, 42],
#  ['Enter R3', 2454.080768, 35],
#  ['Quit R3', 2458.819763, 37],
#  ['Mouse in hall 4', 2458.95671, 45],
#  ['Mouse in offer zone 4', 2459.069453, 46],
#  ['R4 20 offer', 2459.06985, 54],
#  ['Enter R4', 2459.870835, 47],
#  ['Quit R4', 2462.4411010000003, 49],
#  ['Mouse in hall 1', 2462.572134, 9],
#  ['Mouse in hall 1', 2462.639002, 9],
#  ['Mouse in offer zone 1', 2462.893978, 10],
#  ['R1 80 offer', 2462.89472, 19],
#  ['Enter R1', 2463.796954, 11],
#  ['R1 noreward tone', 2466.799552, 15],
#  ['Quit R1', 2470.103923, 13],
#  ['Mouse in hall 2', 2470.403597, 21],
#  ['Mouse in offer zone 2', 2470.530189, 22],
#  ['R2 100 offer', 2470.53065, 32],
#  ['Enter R2', 2471.597581, 23],
#  ['Servo 2 open', 2472.599654, 3],
#  ['R2 reward taken', 2475.2452989999997, 28],
#  ['Quit R2', 2491.321754, 25],
#  ['Mouse in hall 3', 2491.38944, 33],
#  ['Mouse in offer zone 3', 2491.824998, 34],
#  ['R3 100 offer', 2491.825395, 44],
#  ['Mouse in hall 3', 2492.590835, 33],
#  ['Enter R3', 2493.463526, 35],
#  ['Quit R3', 2499.968986, 37],
#  ['Mouse in hall 4', 2500.136038, 45],
#  ['Mouse in offer zone 4', 2500.286336, 46],
#  ['R4 20 offer', 2500.287155, 54],
#  ['Enter R4', 2501.283162, 47],
#  ['Quit R4', 2504.386394, 49],
#  ['Mouse in hall 1', 2504.5195519999997, 9],
#  ['Mouse in offer zone 1', 2504.842957, 10],
#  ['R1 0 offer', 2504.843584, 17],
#  ['Mouse in hall 2', 2506.378419, 21],
#  ['Mouse in offer zone 2', 2506.6067329999996, 22],
#  ['R2 20 offer', 2506.607462, 30],
#  ['Enter R2', 2507.5765890000002, 23],
#  ['Quit R2', 2511.47735, 25],
#  ['Mouse in hall 3', 2511.509658, 33],
#  ['Mouse in offer zone 3', 2511.646874, 34],
#  ['R3 100 offer', 2511.647322, 44],
#  ['Enter R3', 2512.583117, 35],
#  ['Servo 3 open', 2513.585728, 5],
#  ['R3 reward taken', 2514.93079, 40],
#  ['Quit R3', 2528.867162, 37],
#  ['Mouse in hall 4', 2528.968576, 45],
#  ['Mouse in offer zone 4', 2529.148698, 46],
#  ['R4 0 offer', 2529.14903, 53],
#  ['Enter R4', 2530.050291, 47],
#  ['Quit R4', 2535.225024, 49],
#  ['Mouse in hall 1', 2536.860198, 9],
#  ['Mouse in hall 4', 2539.915059, 45],
#  ['Enter R3', 2540.479667, 35],
#  ['Quit R3', 2545.85248, 37],
#  ['Mouse in hall 4', 2546.188326, 45],
#  ['Mouse in offer zone 4', 2546.5396739999996, 46],
#  ['Mouse in hall 1', 2547.868454, 9],
#  ['Mouse in offer zone 1', 2548.0953219999997, 10],
#  ['R1 0 offer', 2548.096589, 17],
#  ['Mouse in hall 2', 2549.592371, 21],
#  ['Mouse in offer zone 2', 2549.753894, 22],
#  ['R2 80 offer', 2549.754266, 31],
#  ['Enter R2', 2550.7956480000003, 23],
#  ['Servo 2 open', 2553.798464, 3],
#  ['R2 reward taken', 2555.419328, 28],
#  ['Quit R2', 2571.848166, 25],
#  ['Mouse in hall 3', 2572.114829, 33],
#  ['Mouse in offer zone 3', 2572.5524219999998, 34],
#  ['R3 20 offer', 2572.55328, 42],
#  ['Enter R3', 2573.520461, 35],
#  ['Quit R3', 2577.825114, 37],
#  ['Mouse in hall 4', 2577.9554940000003, 45],
#  ['Mouse in offer zone 4', 2578.104371, 46],
#  ['R4 80 offer', 2578.10473, 55],
#  ['Enter R4', 2579.040013, 47],
#  ['Servo 4 open', 2582.050419, 7],
#  ['R4 reward taken', 2583.5735809999996, 52],
#  ['Quit R4', 2592.688256, 49],
#  ['Mouse in hall 1', 2592.756058, 9],
#  ['Mouse in hall 1', 2592.82185, 9],
#  ['Mouse in offer zone 1', 2593.14304, 10],
#  ['R1 80 offer', 2593.143962, 19],
#  ['Enter R1', 2594.477069, 11],
#  ['Servo 1 open', 2597.488256, 1],
#  ['R1 reward taken', 2600.606298, 16],
#  ['Quit R1', 2625.4495100000004, 13],
#  ['Mouse in hall 2', 2625.615539, 21],
#  ['Mouse in offer zone 2', 2625.70935, 22],
#  ['R2 20 offer', 2625.70999, 30],
#  ['Enter R2', 2626.874406, 23],
#  ['R 2 noreward tone', 2631.882778, 27],
#  ['Quit R2', 2639.992346, 25],
#  ['Mouse in hall 3', 2640.092275, 33],
#  ['Mouse in offer zone 3', 2640.329357, 34],
#  ['R3 100 offer', 2640.330061, 44],
#  ['Enter R3', 2641.72855, 35],
#  ['Servo 3 open', 2642.730982, 5],
#  ['R3 reward taken', 2644.343104, 40],
#  ['Quit R3', 2668.59433, 37],
#  ['Enter R3', 2673.301133, 35],
#  ['Quit R3', 2676.103424, 37],
#  ['Enter R3', 2676.569536, 35],
#  ['Quit R3', 2680.6416510000004, 37],
#  ['Mouse in hall 4', 2680.8412670000002, 45],
#  ['Mouse in offer zone 4', 2680.9636219999998, 46],
#  ['R4 20 offer', 2680.964429, 54],
#  ['Enter R4', 2681.820032, 47],
#  ['R4 noreward tone', 2686.823398, 51],
#  ['Quit R4', 2694.669504, 49],
#  ['Mouse in hall 4', 2696.457805, 45],
#  ['Enter R3', 2696.891187, 35],
#  ['Quit R3', 2700.196058, 37],
#  ['Mouse in hall 3', 2700.959437, 33],
#  ['Enter R2', 2701.496922, 23],
#  ['Quit R2', 2718.111718, 25],
#  ['Enter R2', 2718.178394, 23],
#  ['Quit R2', 2718.245658, 25],
#  ['Enter R2', 2718.279078, 23],
#  ['Quit R2', 2718.3121539999997, 25],
#  ['Mouse in hall 3', 2719.280051, 33],
#  ['Mouse in offer zone 3', 2719.522509, 34],
#  ['Enter R3', 2720.388992, 35],
#  ['Quit R3', 2721.822579, 37],
#  ['Mouse in hall 4', 2721.924378, 45],
#  ['Mouse in offer zone 4', 2722.066189, 46],
#  ['Enter R4', 2722.867162, 47],
#  ['Quit R4', 2724.4046719999997, 49],
#  ['Mouse in hall 1', 2724.438298, 9],
#  ['Mouse in offer zone 1', 2724.6307070000003, 10],
#  ['R1 0 offer', 2724.631411, 17],
#  ['Mouse in hall 2', 2725.932787, 21],
#  ['Mouse in offer zone 2', 2726.05481, 22],
#  ['R2 20 offer', 2726.055296, 30],
#  ['Enter R2', 2727.061184, 23],
#  ['R 2 noreward tone', 2732.080704, 27],
#  ['Quit R2', 2740.473702, 25],
#  ['Mouse in hall 3', 2740.60713, 33],
#  ['Mouse in offer zone 3', 2740.774656, 34],
#  ['R3 100 offer', 2740.7752960000003, 44],
#  ['Enter R3', 2741.675251, 35],
#  ['Servo 3 open', 2742.6769280000003, 5],
#  ['R3 reward taken', 2743.807066, 40],
#  ['Quit R3', 2761.3980030000002, 37],
#  ['Mouse in hall 4', 2761.497946, 45],
#  ['Mouse in offer zone 4', 2761.8449539999997, 46],
#  ['R4 0 offer', 2761.845325, 53],
#  ['Enter R4', 2762.749542, 47],
#  ['R4 noreward tone', 2769.765594, 51],
#  ['Quit R4', 2772.426253, 49],
#  ['Mouse in hall 4', 2774.316851, 45],
#  ['Enter R3', 2775.2163579999997, 35],
#  ['Quit R3', 2785.629312, 37],
#  ['Mouse in hall 3', 2793.764902, 33],
#  ['Enter R2', 2795.533786, 23],
#  ['Quit R2', 2807.647616, 25],
#  ['Enter R2', 2810.519258, 23],
#  ['Quit R2', 2811.68727, 25],
#  ['Enter R2', 2811.720013, 23],
#  ['Quit R2', 2815.8897920000004, 25],
#  ['Mouse in hall 2', 2817.569242, 21],
#  ['Enter R1', 2818.032653, 11],
#  ['Quit R1', 2830.885734, 13],
#  ['Enter R1', 2831.017882, 11],
#  ['Quit R1', 2831.050918, 13],
#  ['Enter R1', 2831.348454, 11],
#  ['Quit R1', 2831.688307, 13],
#  ['Enter R1', 2831.7250559999998, 11],
#  ['Quit R1', 2834.936819, 13],
#  ['Mouse in hall 1', 2837.500608, 9],
#  ['Mouse in offer zone 4', 2837.868173, 46],
#  ['Enter R4', 2838.3667969999997, 47],
#  ['Quit R4', 2842.5696, 49],
#  ['Mouse in hall 4', 2843.325773, 45],
#  ['Mouse in offer zone 3', 2843.491622, 34],
#  ['Enter R3', 2843.927386, 35],
#  ['Quit R3', 2848.997619, 37],
#  ['Enter R3', 2856.80713, 35],
#  ['Quit R3', 2857.14112, 37],
#  ['Enter R3', 2857.174221, 35],
#  ['Quit R3', 2857.4416260000003, 37],
#  ['Mouse in hall 4', 2857.841446, 45],
#  ['Mouse in offer zone 4', 2858.3251579999996, 46],
#  ['Enter R4', 2859.7883899999997, 47],
#  ['Quit R4', 2862.694259, 49],
#  ['Enter R4', 2880.713766, 47],
#  ['Quit R4', 2885.986342, 49],
#  ['Mouse in hall 1', 2887.15424, 9],
#  ['Mouse in offer zone 1', 2887.345843, 10],
#  ['R1 80 offer', 2887.346317, 19],
#  ['Enter R1', 2888.314189, 11],
#  ['Servo 1 open', 2891.3209469999997, 1],
#  ['R1 reward taken', 2892.636173, 16],
#  ['Quit R1', 2910.271322, 13],
#  ['Mouse in hall 2', 2910.840256, 21],
#  ['Mouse in offer zone 2', 2911.066867, 22],
#  ['R 2 0 offer', 2911.0673920000004, 29],
#  ['Enter R2', 2912.502963, 23],
#  ['R 2 noreward tone', 2919.512154, 27],
#  ['Quit R2', 2921.643891, 25],
#  ['Mouse in hall 2', 2922.889882, 21],
#  ['Enter R1', 2923.18505, 11],
#  ['Quit R1', 2951.425792, 13],
#  ['Enter R1', 2951.523405, 11],
#  ['Quit R1', 2951.686861, 13],
#  ['Enter R1', 2951.785139, 11],
#  ['Quit R1', 2962.2368260000003, 13],
#  ['Mouse in hall 1', 2963.8728579999997, 9],
#  ['Enter R4', 2964.306829, 47],
#  ['Quit R4', 2975.686093, 49],
#  ['Mouse in hall 1', 2975.852672, 9],
#  ['Mouse in hall 1', 2975.986432, 9],
#  ['Mouse in hall 1', 2976.3204100000003, 9],
#  ['Mouse in hall 1', 2976.453325, 9],
#  ['Mouse in hall 1', 2976.553856, 9],
#  ['Mouse in hall 1', 2976.720499, 9],
#  ['Mouse in hall 1', 2976.854413, 9],
#  ['Mouse in hall 1', 2977.188186, 9],
#  ['Mouse in hall 1', 2977.290125, 9],
#  ['Mouse in hall 1', 2977.492173, 9],
#  ['Mouse in hall 1', 2977.561664, 9],
#  ['Mouse in hall 1', 2977.7260929999998, 9],
#  ['Mouse in hall 1', 2977.825562, 9],
#  ['Mouse in hall 1', 2977.958669, 9],
#  ['Mouse in hall 1', 2978.021978, 9],
#  ['Mouse in hall 1', 2978.356147, 9],
#  ['Mouse in hall 1', 2978.58912, 9],
#  ['Mouse in hall 1', 2978.6567809999997, 9],
#  ['Mouse in hall 1', 2978.722918, 9],
#  ['Enter R4', 2978.78953, 47],
#  ['Mouse in hall 1', 2978.8228480000002, 9],
#  ['Quit R4', 2978.822963, 49],
#  ['Enter R4', 2978.856307, 47],
#  ['Quit R4', 2978.923136, 49],
#  ['Enter R4', 2979.257165, 47],
#  ['Quit R4', 2979.657114, 49],
#  ['Enter R4', 2979.690662, 47],
#  ['Mouse in hall 1', 2979.79081, 9],
#  ['Quit R4', 2979.924595, 49],
#  ['Enter R4', 2979.957325, 47],
#  ['Quit R4', 2979.9909629999997, 49],
#  ['Enter R4', 2980.024512, 47],
#  ['Quit R4', 2980.058176, 49],
#  ['Enter R4', 2980.091277, 47],
#  ['Quit R4', 2980.161536, 49],
#  ['Mouse in hall 1', 2980.1950460000003, 9],
#  ['Enter R4', 2980.1953280000002, 47],
#  ['Quit R4', 2980.260877, 49],
#  ['Enter R4', 2980.46121, 47],
#  ['Mouse in hall 1', 2980.495539, 9],
#  ['Quit R4', 2980.495834, 49],
#  ['Mouse in hall 1', 2980.894566, 9],
#  ['Mouse in hall 1', 2981.09728, 9],
#  ['Enter R4', 2982.199219, 47],
#  ['Quit R4', 2982.467853, 49],
#  ['Mouse in hall 4', 2985.953869, 45],
#  ['Enter R3', 2986.521318, 35],
#  ['Quit R3', 2993.763277, 37],
#  ['Mouse in hall 3', 3000.240307, 33],
#  ['Mouse in offer zone 2', 3000.468864, 22],
#  ['Enter R2', 3000.871782, 23],
#  ['Quit R2', 3006.607936, 25],
#  ['Mouse in hall 3', 3007.0750980000003, 33],
#  ['Mouse in offer zone 3', 3007.579712, 34],
#  ['R3 20 offer', 3007.58016, 42],
#  ['Enter R3', 3009.080589, 35],
#  ['R3 noreward tone', 3014.095232, 39],
#  ['Quit R3', 3018.791232, 37],
#  ['Mouse in hall 4', 3018.924659, 45],
#  ['Mouse in offer zone 4', 3019.07296, 46],
#  ['R4 20 offer', 3019.0736899999997, 54],
#  ['Enter R4', 3019.97175, 47],
#  ['Servo 4 open', 3024.9792899999998, 7],
#  ['R4 reward taken', 3026.5794690000002, 52],
#  ['Quit R4', 3045.565632, 49],
#  ['Mouse in hall 1', 3045.6320769999998, 9],
#  ['Mouse in hall 1', 3045.739021, 9],
#  ['Mouse in hall 1', 3045.803187, 9],
#  ['Mouse in hall 1', 3046.037248, 9],
#  ['Mouse in hall 1', 3046.166093, 9],
#  ['Mouse in hall 1', 3046.268582, 9],
#  ['Mouse in hall 1', 3046.533082, 9],
#  ['Mouse in hall 1', 3046.8382079999997, 9],
#  ['Mouse in hall 1', 3047.06935, 9],
#  ['Mouse in hall 1', 3047.5738109999998, 9],
#  ['Mouse in hall 1', 3049.371802, 9],
#  ['Mouse in offer zone 1', 3049.830144, 10],
#  ['R1 0 offer', 3049.830554, 17],
#  ['Enter R1', 3050.964941, 11],
#  ['Quit R1', 3056.8382460000003, 13],
#  ['Mouse in hall 2', 3057.071629, 21],
#  ['Mouse in offer zone 2', 3057.432294, 22],
#  ['R2 100 offer', 3057.432845, 32],
#  ['Enter R2', 3058.873728, 23],
#  ['Servo 2 open', 3059.8916480000003, 3],
#  ['R2 reward taken', 3061.205888, 28],
#  ['Quit R2', 3073.157184, 25],
#  ['Mouse in hall 3', 3074.151027, 33],
#  ['Mouse in hall 3', 3074.2510460000003, 33],
#  ['Enter R2', 3074.7555199999997, 23],
#  ['Mouse in hall 3', 3074.885427, 33],
#  ['Quit R2', 3078.523354, 25],
#  ['Enter R2', 3078.5562370000002, 23],
#  ['Quit R2', 3078.5900030000003, 25],
#  ['Enter R2', 3098.145101, 23],
#  ['Quit R2', 3106.322445, 25],
#  ['Mouse in hall 3', 3106.389901, 33],
#  ['Mouse in offer zone 3', 3106.8260219999997, 34],
#  ['R3 100 offer', 3106.8263420000003, 44],
#  ['Enter R3', 3108.227494, 35],
#  ['Servo 3 open', 3109.229286, 5],
#  ['R3 reward taken', 3113.713139, 40],
#  ['Quit R3', 3143.835622, 37],
#  ['Mouse in hall 4', 3144.0004480000002, 45],
#  ['Mouse in offer zone 4', 3144.179584, 46],
#  ['R4 0 offer', 3144.180173, 53],
#  ['Enter R4', 3145.0441339999998, 47],
#  ['R4 noreward tone', 3152.0557440000002, 51],
#  ['Mouse in hall 1', 3158.793318, 9],
#  ['Quit R4', 3158.7934210000003, 49],
#  ['Mouse in offer zone 1', 3158.921216, 10],
#  ['R1 80 offer', 3158.922099, 19],
#  ['Enter R1', 3159.821491, 11],
#  ['Servo 1 open', 3162.823552, 1],
#  ['R1 reward taken', 3164.069594, 16],
#  ['Quit R1', 3181.084634, 13],
#  ['Mouse in hall 2', 3181.279616, 21],
#  ['Mouse in offer zone 2', 3181.407386, 22],
#  ['R2 20 offer', 3181.4078210000002, 30],
#  ['Enter R2', 3182.6777859999997, 23],
#  ['R 2 noreward tone', 3187.696371, 27],
#  ['Quit R2', 3192.5858940000003, 25],
#  ['Mouse in hall 3', 3192.7869570000003, 33],
#  ['Mouse in offer zone 3', 3193.126234, 34],
#  ['R3 0 offer', 3193.127014, 41],
#  ['Enter R3', 3193.9987969999997, 35],
#  ['Quit R3', 3198.064781, 37],
#  ['Mouse in hall 4', 3198.264666, 45],
#  ['Mouse in offer zone 4', 3198.407949, 46],
#  ['R4 0 offer', 3198.408768, 53],
#  ['Enter R4', 3199.343898, 47],
#  ['Mouse in hall 1', 3205.749376, 9],
#  ['Quit R4', 3205.74953, 49],
#  ['Mouse in offer zone 1', 3205.943667, 10],
#  ['R1 20 offer', 3205.944858, 18],
#  ['Enter R1', 3206.94295, 11],
#  ['Quit R1', 3207.242586, 13],
#  ['Enter R1', 3207.476544, 11],
#  ['Quit R1', 3210.41257, 13],
#  ['Mouse in hall 2', 3210.5464699999998, 21],
#  ['Mouse in offer zone 2', 3210.640269, 22],
#  ['R2 20 offer', 3210.640742, 30],
#  ['Enter R2', 3211.679718, 23],
#  ['Quit R2', 3216.580083, 25],
#  ['Mouse in hall 3', 3216.646707, 33],
#  ['Mouse in offer zone 3', 3216.785293, 34],
#  ['R3 80 offer', 3216.7856899999997, 43],
#  ['Enter R3', 3217.989645, 35],
#  ['Servo 3 open', 3221.00288, 5],
#  ['R3 reward taken', 3222.565837, 40],
#  ['Quit R3', 3234.742067, 37],
#  ['Mouse in hall 4', 3234.939738, 45],
#  ['Mouse in offer zone 4', 3235.1182719999997, 46],
#  ['R4 20 offer', 3235.118848, 54],
#  ['Enter R4', 3236.3173890000003, 47],
#  ['R4 noreward tone', 3241.3335420000003, 51],
#  ['Quit R4', 3244.59072, 49],
#  ['Mouse in hall 1', 3244.624064, 9],
#  ['Mouse in offer zone 1', 3244.884928, 10],
#  ['R1 20 offer', 3244.885888, 18],
#  ['Enter R1', 3245.9201789999997, 11],
#  ['R1 noreward tone', 3250.9336829999997, 15],
#  ['Quit R1', 3253.828557, 13],
#  ['Mouse in hall 2', 3253.996723, 21],
#  ['Mouse in offer zone 2', 3254.2918019999997, 22],
#  ['R 2 0 offer', 3254.292262, 29],
#  ['Mouse in hall 3', 3255.457907, 33],
#  ['Mouse in offer zone 3', 3255.728973, 34],
#  ['R3 100 offer', 3255.729472, 44],
#  ['Enter R3', 3256.963494, 35],
#  ['Servo 3 open', 3257.96544, 5],
#  ['R3 reward taken', 3259.248666, 40],
#  ['Quit R3', 3281.663194, 37],
#  ['Mouse in hall 4', 3281.794432, 45],
#  ['Mouse in offer zone 4', 3281.971354, 46],
#  ['R4 20 offer', 3281.971955, 54],
#  ['Enter R4', 3282.870157, 47],
#  ['R4 noreward tone', 3287.886989, 51],
#  ['Quit R4', 3291.879526, 49],
#  ['Mouse in hall 1', 3291.913485, 9],
#  ['Mouse in offer zone 1', 3292.074662, 10],
#  ['R1 80 offer', 3292.075763, 19],
#  ['Enter R1', 3293.073229, 11],
#  ['Servo 1 open', 3296.090419, 1],
#  ['R1 reward taken', 3297.431411, 16],
#  ['Quit R1', 3308.1932420000003, 13],
#  ['Mouse in hall 2', 3308.39337, 21],
#  ['Mouse in offer zone 2', 3308.558643, 22],
#  ['R2 80 offer', 3308.561574, 31],
#  ['Enter R2', 3309.852774, 23],
#  ['R 2 noreward tone', 3312.868186, 27],
#  ['Quit R2', 3319.1338370000003, 25],
#  ['Mouse in hall 3', 3319.399974, 33],
#  ['Mouse in hall 3', 3319.764211, 33],
#  ['Mouse in offer zone 3', 3319.968947, 34],
#  ['R3 0 offer', 3319.969446, 41],
#  ['Enter R3', 3320.8414980000002, 35],
#  ['Quit R3', 3322.472384, 37],
#  ['Mouse in hall 4', 3322.605376, 45],
#  ['Mouse in offer zone 4', 3322.746509, 46],
#  ['R4 100 offer', 3322.746918, 56],
#  ['Enter R4', 3323.681293, 47],
#  ['Servo 4 open', 3324.684774, 7],
#  ['R4 reward taken', 3326.080986, 52],
#  ['Mouse in hall 1', 3333.3935739999997, 9],
#  ['Mouse in hall 1', 3341.63753, 9],
#  ['Mouse in hall 1', 3341.70537, 9],
#  ['Mouse in hall 1', 3341.837171, 9],
#  ['Mouse in hall 1', 3342.06793, 9],
#  ['Mouse in hall 1', 3342.202688, 9],
#  ['Mouse in hall 1', 3343.269312, 9],
#  ['Quit R4', 3345.441664, 49],
#  ['Mouse in hall 1', 3347.9794690000003, 9],
#  ['Mouse in hall 4', 3349.372032, 45],
#  ['Mouse in hall 4', 3351.10528, 45],
#  ['Mouse in hall 3', 3360.380096, 33],
#  ['Enter R2', 3361.414579, 23],
#  ['Quit R2', 3368.289267, 25],
#  ['Enter R2', 3368.356224, 23],
#  ['Quit R2', 3368.5242369999996, 25],
#  ['Enter R2', 3368.5558020000003, 23],
#  ['Quit R2', 3369.7260420000002, 25],
#  ['Enter R2', 3369.788083, 23],
#  ['Quit R2', 3373.6926340000005, 25],
#  ['Mouse in hall 3', 3375.296768, 33],
#  ['Mouse in offer zone 3', 3376.269133, 34],
#  ['Mouse in hall 3', 3376.6660479999996, 33],
#  ['Enter R3', 3379.1690369999997, 35],
#  ['Quit R3', 3384.620531, 37],
#  ['Mouse in hall 3', 3396.5857409999994, 33],
#  ['Mouse in hall 3', 3400.7592189999996, 33],
#  ['Mouse in hall 3', 3400.927078, 33],
#  ['Mouse in hall 3', 3401.023565, 33],
#  ['Enter R2', 3411.381542, 23],
#  ['Mouse in hall 3', 3411.406822, 33],
#  ['Quit R2', 3417.845056, 25],
#  ['Enter R2', 3417.87785, 23],
#  ['Quit R2', 3418.346074, 25],
#  ['Mouse in hall 3', 3418.7808, 33],
#  ['Mouse in offer zone 3', 3419.0818689999996, 34],
#  ['Mouse in hall 4', 3420.319347, 45],
#  ...]

# %%
event_code_dict[29]='R2 0 offer'
event_code_dict[27]='R2 noreward tone'

event_code_dict
# Out:
# {11: 'Enter R1',
#  23: 'Enter R2',
#  35: 'Enter R3',
#  47: 'Enter R4',
#  9: 'Mouse in hall 1',
#  21: 'Mouse in hall 2',
#  33: 'Mouse in hall 3',
#  45: 'Mouse in hall 4',
#  10: 'Mouse in offer zone 1',
#  22: 'Mouse in offer zone 2',
#  34: 'Mouse in offer zone 3',
#  46: 'Mouse in offer zone 4',
#  13: 'Quit R1',
#  25: 'Quit R2',
#  37: 'Quit R3',
#  49: 'Quit R4',
#  29: 'R2 0 offer',
#  27: 'R2 noreward tone',
#  17: 'R1 0 offer',
#  20: 'R1 100 offer',
#  18: 'R1 20 offer',
#  19: 'R1 80 offer',
#  15: 'R1 noreward tone',
#  16: 'R1 reward taken',
#  32: 'R2 100 offer',
#  30: 'R2 20 offer',
#  31: 'R2 80 offer',
#  28: 'R2 reward taken',
#  41: 'R3 0 offer',
#  44: 'R3 100 offer',
#  42: 'R3 20 offer',
#  43: 'R3 80 offer',
#  39: 'R3 noreward tone',
#  40: 'R3 reward taken',
#  53: 'R4 0 offer',
#  56: 'R4 100 offer',
#  54: 'R4 20 offer',
#  55: 'R4 80 offer',
#  51: 'R4 noreward tone',
#  52: 'R4 reward taken',
#  1: 'Servo 1 open',
#  3: 'Servo 2 open',
#  5: 'Servo 3 open',
#  7: 'Servo 4 open'}

# %%
def restaurant_extractor(events_list):
    for i in events_list:
        if len(i) <= 3:
            integers = re.findall('[0-9]+', i[0])
            for j in integers:
                if 5 > int(j) > 0:
                    i.append(int(j))

restaurant_extractor(events_list)
# events_list[:10]
events_list
# Out:
# [['Mouse in offer zone 1', 246.80968959999998, 10, 1],
#  ['R1 100 offer', 247.0, 20, 1],
#  ['Enter R1', 247.0, 11, 1],
#  ['Quit R1', 252.716992, 13, 1],
#  ['Mouse in hall 2', 253.3837312, 21, 2],
#  ['Mouse in offer zone 2', 253.5054336, 22, 2],
#  ['R 2 0 offer', 253.51754240000002, 29, 2],
#  ['Enter R2', 255.90618880000002, 23, 2],
#  ['R 2 noreward tone', 262.972096, 27, 2],
#  ['Quit R2', 363.43120639999995, 25, 2],
#  ['Mouse in hall 3', 363.49783039999994, 33, 3],
#  ['Mouse in offer zone 3', 365.9704832, 34, 3],
#  ['R3 0 offer', 365.98688, 41, 3],
#  ['Enter R3', 367.67199999999997, 35, 3],
#  ['R3 noreward tone', 374.7444992, 39, 3],
#  ['Quit R3', 414.3253376, 37, 3],
#  ['Mouse in hall 4', 414.49186560000004, 45, 4],
#  ['Mouse in offer zone 4', 414.62776319999995, 46, 4],
#  ['R4 0 offer', 414.6416512, 53, 4],
#  ['Enter R4', 416.5275648, 47, 4],
#  ['R4 noreward tone', 423.6059648, 51, 4],
#  ['Quit R4', 426.1719552, 49, 4],
#  ['Mouse in hall 1', 426.6690688, 9, 1],
#  ['Mouse in hall 1', 428.77493760000004, 9, 1],
#  ['Mouse in offer zone 1', 429.882496, 10, 1],
#  ['R1 20 offer', 429.885568, 18, 1],
#  ['Enter R1', 431.483712, 11, 1],
#  ['R1 noreward tone', 436.53208319999993, 15, 1],
#  ['Quit R1', 520.4531968, 13, 1],
#  ['Mouse in hall 2', 520.5879808, 21, 2],
#  ['Mouse in offer zone 2', 520.909952, 22, 2],
#  ['R2 20 offer', 520.9168639999999, 30, 2],
#  ['Enter R2', 522.8465536, 23, 2],
#  ['R 2 noreward tone', 527.8572416000001, 27, 2],
#  ['Quit R2', 611.2837503999999, 25, 2],
#  ['Mouse in hall 2', 613.4583167999999, 21, 2],
#  ['Enter R1', 614.0576512, 11, 1],
#  ['Quit R1', 623.3758207999999, 13, 1],
#  ['Mouse in hall 1', 624.7597440000001, 9, 1],
#  ['Enter R4', 627.3678976, 47, 4],
#  ['Quit R4', 639.2768127999999, 49, 4],
#  ['Enter R4', 639.3104128, 47, 4],
#  ['Quit R4', 639.3435776, 49, 4],
#  ['Mouse in hall 4', 642.2147456, 45, 4],
#  ['Enter R3', 642.6813952, 35, 3],
#  ['Quit R3', 654.0993152000001, 37, 3],
#  ['Mouse in hall 3', 656.3304063999999, 33, 3],
#  ['Mouse in offer zone 2', 656.4654336, 22, 2],
#  ['Enter R2', 656.6965376, 23, 2],
#  ['Quit R2', 665.4728064, 25, 2],
#  ['Enter R2', 665.538944, 23, 2],
#  ['Quit R2', 665.7117184, 25, 2],
#  ['Enter R2', 665.7748352000001, 23, 2],
#  ['Quit R2', 665.9111807999999, 25, 2],
#  ['Enter R2', 665.9761152000001, 23, 2],
#  ['Quit R2', 666.0420352000001, 25, 2],
#  ['Enter R2', 666.142144, 23, 2],
#  ['Quit R2', 667.0433152, 25, 2],
#  ['Enter R2', 667.0756992, 23, 2],
#  ['Quit R2', 667.1152256, 25, 2],
#  ['Enter R2', 667.1460736, 23, 2],
#  ['Quit R2', 667.2456063999999, 25, 2],
#  ['Enter R2', 667.2795136, 23, 2],
#  ['Quit R2', 667.84128, 25, 2],
#  ['Enter R2', 667.9780607999999, 23, 2],
#  ['Quit R2', 668.0103936, 25, 2],
#  ['Enter R2', 668.0452864, 23, 2],
#  ['Quit R2', 668.0770944, 25, 2],
#  ['Enter R2', 668.1437440000001, 23, 2],
#  ['Quit R2', 668.2450816, 25, 2],
#  ['Enter R2', 668.2792576, 23, 2],
#  ['Quit R2', 668.3108096, 25, 2],
#  ['Enter R2', 668.34528, 23, 2],
#  ['Quit R2', 668.644288, 25, 2],
#  ['Enter R2', 668.6787456000001, 23, 2],
#  ['Quit R2', 669.08064, 25, 2],
#  ['Enter R2', 669.1454976, 23, 2],
#  ['Quit R2', 669.41216, 25, 2],
#  ['Enter R2', 669.4464512, 23, 2],
#  ['Quit R2', 673.0809343999999, 25, 2],
#  ['Enter R2', 673.1153408, 23, 2],
#  ['Quit R2', 678.725184, 25, 2],
#  ['Enter R2', 678.7564160000001, 23, 2],
#  ['Quit R2', 678.9876992000001, 25, 2],
#  ['Enter R2', 679.0216832, 23, 2],
#  ['Quit R2', 679.0900864, 25, 2],
#  ['Enter R2', 679.5922816000001, 23, 2],
#  ['Quit R2', 680.6925056, 25, 2],
#  ['Enter R2', 680.8262272000001, 23, 2],
#  ['Quit R2', 680.9229184, 25, 2],
#  ['Enter R2', 680.9564416000001, 23, 2],
#  ['Quit R2', 681.426304, 25, 2],
#  ['Enter R2', 681.4651136, 23, 2],
#  ['Quit R2', 683.564416, 25, 2],
#  ['Enter R2', 683.8607616, 23, 2],
#  ['Quit R2', 683.9267072, 25, 2],
#  ['Enter R2', 684.0329088, 23, 2],
#  ['Quit R2', 684.1950336, 25, 2],
#  ['Enter R2', 684.2268928, 23, 2],
#  ['Quit R2', 684.3295744, 25, 2],
#  ['Enter R2', 684.6316544, 23, 2],
#  ['Quit R2', 685.0705664, 25, 2],
#  ['Enter R2', 685.0970368, 23, 2],
#  ['Quit R2', 685.1969024, 25, 2],
#  ['Enter R2', 685.2625024, 23, 2],
#  ['Quit R2', 685.3621504, 25, 2],
#  ['Enter R2', 685.431616, 23, 2],
#  ['Quit R2', 685.7313408, 25, 2],
#  ['Enter R2', 685.7953536, 23, 2],
#  ['Quit R2', 685.8965504, 25, 2],
#  ['Enter R2', 685.9306112, 23, 2],
#  ['Quit R2', 685.9634176, 25, 2],
#  ['Enter R2', 685.9958528, 23, 2],
#  ['Quit R2', 686.0297727999999, 25, 2],
#  ['Enter R2', 686.0630656000001, 23, 2],
#  ['Quit R2', 688.0013312000001, 25, 2],
#  ['Mouse in hall 2', 689.4829952, 21, 2],
#  ['Mouse in offer zone 1', 689.7120768, 10, 1],
#  ['Enter R1', 690.0776448, 11, 1],
#  ['Quit R1', 699.3586944, 13, 1],
#  ['Mouse in hall 1', 702.1494912, 9, 1],
#  ['Mouse in offer zone 4', 702.51648, 46, 4],
#  ['Enter R4', 703.4201856000001, 47, 4],
#  ['Quit R4', 724.7102719999999, 49, 4],
#  ['Mouse in hall 4', 726.178368, 45, 4],
#  ['Mouse in offer zone 3', 726.3472256, 34, 3],
#  ['Enter R3', 726.5449087999999, 35, 3],
#  ['Quit R3', 740.8616704, 37, 3],
#  ['Mouse in hall 3', 742.0613503999999, 33, 3],
#  ['Mouse in offer zone 2', 742.1940096, 22, 2],
#  ['Enter R2', 742.426944, 23, 2],
#  ['Quit R2', 821.9181312000001, 25, 2],
#  ['Mouse in hall 3', 821.9850624, 33, 3],
#  ['Mouse in offer zone 3', 822.2872064, 34, 3],
#  ['R3 0 offer', 822.2876032, 41, 3],
#  ['Enter R3', 823.1877632000001, 35, 3],
#  ['R3 noreward tone', 830.1908864, 39, 3],
#  ['Quit R3', 866.8420480000001, 37, 3],
#  ['Mouse in hall 4', 866.9731968, 45, 4],
#  ['Mouse in offer zone 4', 867.1009024, 46, 4],
#  ['R4 0 offer', 867.1013376, 53, 4],
#  ['Enter R4', 867.9707007999999, 47, 4],
#  ['Quit R4', 873.4437119999999, 49, 4],
#  ['Mouse in hall 1', 873.6415104, 9, 1],
#  ['Mouse in offer zone 1', 873.854528, 10, 1],
#  ['R1 100 offer', 873.8553088, 20, 1],
#  ['Enter R1', 874.9876992000001, 11, 1],
#  ['Servo 1 open', 875.9893504, 1, 1],
#  ['R1 reward taken', 880.270912, 16, 1],
#  ['Quit R1', 933.6880384, 13, 1],
#  ['Mouse in hall 2', 937.793728, 21, 2],
#  ['Mouse in offer zone 2', 937.9202687999999, 22, 2],
#  ['R2 20 offer', 937.9208960000001, 30, 2],
#  ['Enter R2', 938.4842495999999, 23, 2],
#  ['Servo 2 open', 943.49952, 3, 2],
#  ['R2 reward taken', 948.4028927999999, 28, 2],
#  ['Quit R2', 990.3426816, 25, 2],
#  ['Mouse in hall 3', 990.9499392000001, 33, 3],
#  ['Mouse in offer zone 3', 991.2134912, 34, 3],
#  ['R3 80 offer', 991.2164223999999, 43, 3],
#  ['Enter R3', 991.9800704, 35, 3],
#  ['Servo 3 open', 994.9948800000001, 5, 3],
#  ['R3 reward taken', 1001.135411, 40, 3],
#  ['Quit R3', 1027.6924800000002, 37, 3],
#  ['Mouse in hall 4', 1027.854669, 45, 4],
#  ['Mouse in offer zone 4', 1028.149517, 46, 4],
#  ['R4 80 offer', 1028.151987, 55, 4],
#  ['Enter R4', 1029.1205380000001, 47, 4],
#  ['Servo 4 open', 1032.1372800000001, 7, 4],
#  ['R4 reward taken', 1033.889638, 52, 4],
#  ['Quit R4', 1050.808909, 49, 4],
#  ['Mouse in hall 1', 1050.977306, 9, 1],
#  ['Mouse in offer zone 1', 1051.193626, 10, 1],
#  ['R1 80 offer', 1051.1954560000001, 19, 1],
#  ['Enter R1', 1052.155674, 11, 1],
#  ['R1 noreward tone', 1055.169613, 15, 1],
#  ['Quit R1', 1062.206758, 13, 1],
#  ['Mouse in hall 2', 1062.337626, 21, 2],
#  ['Mouse in offer zone 2', 1062.431411, 22, 2],
#  ['R2 80 offer', 1062.4321539999999, 31, 2],
#  ['Enter R2', 1063.3292800000002, 23, 2],
#  ['Servo 2 open', 1066.34473, 3, 2],
#  ['R2 reward taken', 1078.512, 28, 2],
#  ['Quit R2', 1100.635149, 25, 2],
#  ['Mouse in hall 3', 1100.738419, 33, 3],
#  ['Mouse in offer zone 3', 1100.877235, 34, 3],
#  ['R3 0 offer', 1100.878042, 41, 3],
#  ['Enter R3', 1101.542912, 35, 3],
#  ['Quit R3', 1104.655706, 37, 3],
#  ['Mouse in hall 4', 1104.8121859999999, 45, 4],
#  ['Mouse in offer zone 4', 1104.903706, 46, 4],
#  ['R4 20 offer', 1104.904896, 54, 4],
#  ['Enter R4', 1105.70391, 47, 4],
#  ['R4 noreward tone', 1110.7167359999999, 51, 4],
#  ['Quit R4', 1112.280896, 49, 4],
#  ['Mouse in hall 1', 1112.347533, 9, 1],
#  ['Mouse in offer zone 1', 1112.661453, 10, 1],
#  ['R1 20 offer', 1112.6624259999999, 18, 1],
#  ['Enter R1', 1113.691917, 11, 1],
#  ['R1 noreward tone', 1118.708736, 15, 1],
#  ['Quit R1', 1127.743373, 13, 1],
#  ['Mouse in hall 2', 1127.911654, 21, 2],
#  ['Mouse in offer zone 2', 1128.036646, 22, 2],
#  ['R2 100 offer', 1128.037325, 32, 2],
#  ['Enter R2', 1128.906714, 23, 2],
#  ['Servo 2 open', 1129.9171199999998, 3, 2],
#  ['R2 reward taken', 1139.674227, 28, 2],
#  ['Quit R2', 1167.345741, 25, 2],
#  ['Enter R2', 1168.27872, 23, 2],
#  ['Quit R2', 1169.451546, 25, 2],
#  ['Enter R2', 1173.317683, 23, 2],
#  ['Quit R2', 1175.092198, 25, 2],
#  ['Mouse in hall 2', 1181.137242, 21, 2],
#  ['Enter R1', 1181.606182, 11, 1],
#  ['Quit R1', 1183.604493, 13, 1],
#  ['Mouse in hall 1', 1188.597965, 9, 1],
#  ['Enter R4', 1189.398528, 47, 4],
#  ['Mouse in hall 1', 1192.471821, 9, 1],
#  ['Mouse in hall 1', 1192.670797, 9, 1],
#  ['Quit R4', 1192.9046779999999, 49, 4],
#  ['Mouse in hall 1', 1192.936077, 9, 1],
#  ['Mouse in hall 4', 1196.715251, 45, 4],
#  ['Enter R3', 1197.048486, 35, 3],
#  ['Quit R3', 1207.659802, 37, 3],
#  ['Mouse in hall 3', 1210.296179, 33, 3],
#  ['Mouse in offer zone 2', 1211.533056, 22, 2],
#  ['Enter R2', 1213.063398, 23, 2],
#  ['Quit R2', 1242.629901, 25, 2],
#  ['Mouse in hall 2', 1243.7067140000001, 21, 2],
#  ['Mouse in offer zone 1', 1243.907354, 10, 1],
#  ['Enter R1', 1244.374362, 11, 1],
#  ['Quit R1', 1257.1884929999999, 13, 1],
#  ['Mouse in hall 1', 1260.479309, 9, 1],
#  ['Mouse in offer zone 4', 1260.84681, 46, 4],
#  ['Enter R4', 1261.179776, 47, 4],
#  ['Mouse in hall 1', 1274.465037, 9, 1],
#  ['Quit R4', 1274.83241, 49, 4],
#  ['Mouse in hall 1', 1275.064653, 9, 1],
#  ['Mouse in offer zone 1', 1275.843136, 10, 1],
#  ['Enter R1', 1277.078234, 11, 1],
#  ['Quit R1', 1279.38048, 13, 1],
#  ['Mouse in hall 2', 1279.447334, 21, 2],
#  ['Mouse in offer zone 2', 1279.544384, 22, 2],
#  ['Enter R2', 1280.3413890000002, 23, 2],
#  ['Quit R2', 1287.322483, 25, 2],
#  ['Enter R2', 1291.359718, 23, 2],
#  ['Quit R2', 1291.391667, 25, 2],
#  ['Enter R2', 1291.4231550000002, 23, 2],
#  ['Quit R2', 1291.4582269999999, 25, 2],
#  ['Enter R2', 1291.5592960000001, 23, 2],
#  ['Quit R2', 1295.523878, 25, 2],
#  ['Enter R2', 1300.76791, 23, 2],
#  ['Quit R2', 1312.7794689999998, 25, 2],
#  ['Enter R2', 1312.883149, 23, 2],
#  ['Quit R2', 1312.949632, 25, 2],
#  ['Enter R2', 1321.424307, 23, 2],
#  ['Quit R2', 1321.754394, 25, 2],
#  ['Enter R2', 1321.787699, 23, 2],
#  ['Quit R2', 1321.821862, 25, 2],
#  ['Enter R2', 1322.287949, 23, 2],
#  ['Quit R2', 1329.629146, 25, 2],
#  ['Mouse in hall 3', 1329.83145, 33, 3],
#  ['Mouse in offer zone 3', 1330.033702, 34, 3],
#  ['R3 80 offer', 1330.034253, 43, 3],
#  ['Enter R3', 1330.8345980000001, 35, 3],
#  ['Servo 3 open', 1333.8369539999999, 5, 3],
#  ['R3 reward taken', 1335.8573310000002, 40, 3],
#  ['Quit R3', 1353.592294, 37, 3],
#  ['Mouse in hall 4', 1353.726029, 45, 4],
#  ['Mouse in offer zone 4', 1353.885491, 46, 4],
#  ['R4 20 offer', 1353.885888, 54, 4],
#  ['Enter R4', 1355.020928, 47, 4],
#  ['R4 noreward tone', 1360.036749, 51, 4],
#  ['Quit R4', 1372.472448, 49, 4],
#  ['Mouse in hall 1', 1372.639027, 9, 1],
#  ['Mouse in offer zone 1', 1372.888192, 10, 1],
#  ['R1 0 offer', 1372.888678, 17, 1],
#  ['Mouse in hall 1', 1373.2077179999999, 9, 1],
#  ['Mouse in hall 2', 1373.9597310000001, 21, 2],
#  ['Mouse in offer zone 2', 1374.1150460000001, 22, 2],
#  ['R2 80 offer', 1374.115584, 31, 2],
#  ['Enter R2', 1374.9806720000001, 23, 2],
#  ['Servo 2 open', 1377.991066, 3, 2],
#  ['R2 reward taken', 1379.536947, 28, 2],
#  ['Quit R2', 1397.940467, 25, 2],
#  ['Mouse in hall 2', 1400.553933, 21, 2],
#  ['Mouse in offer zone 1', 1401.020544, 10, 1],
#  ['Enter R1', 1401.387802, 11, 1],
#  ['Quit R1', 1418.007232, 13, 1],
#  ['Mouse in hall 1', 1421.463565, 9, 1],
#  ['Enter R4', 1427.735514, 47, 4],
#  ['Quit R4', 1434.71081, 49, 4],
#  ['Mouse in hall 4', 1436.923866, 45, 4],
#  ['Enter R3', 1437.927142, 35, 3],
#  ['Quit R3', 1445.6669570000001, 37, 3],
#  ['Mouse in hall 4', 1445.802829, 45, 4],
#  ['Mouse in offer zone 4', 1445.927258, 46, 4],
#  ['Enter R4', 1446.995584, 47, 4],
#  ['Quit R4', 1452.096742, 49, 4],
#  ['Mouse in hall 1', 1452.1963779999999, 9, 1],
#  ['Mouse in offer zone 1', 1452.544128, 10, 1],
#  ['Enter R1', 1453.6479869999998, 11, 1],
#  ['Quit R1', 1455.914419, 13, 1],
#  ['Mouse in hall 2', 1456.014643, 21, 2],
#  ['Mouse in offer zone 2', 1456.1069439999999, 22, 2],
#  ['Enter R2', 1457.0444929999999, 23, 2],
#  ['Quit R2', 1465.719117, 25, 2],
#  ['Enter R2', 1465.786675, 23, 2],
#  ['Quit R2', 1465.85111, 25, 2],
#  ['Enter R2', 1540.4719619999998, 23, 2],
#  ['Quit R2', 1620.565926, 25, 2],
#  ['Mouse in hall 3', 1620.6308609999999, 33, 3],
#  ['Mouse in offer zone 3', 1621.131763, 34, 3],
#  ['R3 80 offer', 1621.132198, 43, 3],
#  ['Enter R3', 1622.39881, 35, 3],
#  ['R3 noreward tone', 1625.4012539999999, 39, 3],
#  ['Quit R3', 1637.916902, 37, 3],
#  ['Mouse in hall 4', 1638.08329, 45, 4],
#  ['Mouse in offer zone 4', 1638.2737539999998, 46, 4],
#  ['R4 80 offer', 1638.274202, 55, 4],
#  ['Enter R4', 1639.245069, 47, 4],
#  ['R4 noreward tone', 1642.262093, 51, 4],
#  ['Quit R4', 1653.6913279999999, 49, 4],
#  ['Mouse in hall 1', 1653.75703, 9, 1],
#  ['Mouse in offer zone 1', 1654.0066689999999, 10, 1],
#  ['R1 80 offer', 1654.007885, 19, 1],
#  ['Enter R1', 1655.141018, 11, 1],
#  ['Servo 1 open', 1658.157542, 1, 1],
#  ['R1 reward taken', 1659.73353, 16, 1],
#  ['Quit R1', 1680.236109, 13, 1],
#  ['Enter R1', 1681.6376059999998, 11, 1],
#  ['Quit R1', 1686.245581, 13, 1],
#  ['Enter R1', 1686.5099010000001, 11, 1],
#  ['Quit R1', 1686.6790399999998, 13, 1],
#  ['Mouse in hall 2', 1687.8125949999999, 21, 2],
#  ['Mouse in offer zone 2', 1688.0081149999999, 22, 2],
#  ['R 2 0 offer', 1688.011328, 29, 2],
#  ['Enter R2', 1689.3067260000003, 23, 2],
#  ['R 2 noreward tone', 1696.3225730000001, 27, 2],
#  ['Quit R2', 1703.7894019999999, 25, 2],
#  ['Enter R2', 1709.232883, 23, 2],
#  ['Quit R2', 1715.969677, 25, 2],
#  ['Mouse in hall 3', 1716.537242, 33, 3],
#  ['Mouse in offer zone 3', 1716.7071230000001, 34, 3],
#  ['R3 0 offer', 1716.707661, 41, 3],
#  ['Enter R3', 1717.580659, 35, 3],
#  ['R3 noreward tone', 1724.598387, 39, 3],
#  ['Quit R3', 1725.621478, 37, 3],
#  ['Mouse in hall 4', 1725.824614, 45, 4],
#  ['Mouse in offer zone 4', 1725.939098, 46, 4],
#  ['R4 0 offer', 1725.9394690000001, 53, 4],
#  ['Enter R4', 1727.107507, 47, 4],
#  ['R4 noreward tone', 1734.1246850000002, 51, 4],
#  ['Quit R4', 1739.189504, 49, 4],
#  ['Mouse in hall 4', 1741.236787, 45, 4],
#  ['Enter R3', 1741.7026050000002, 35, 3],
#  ['Quit R3', 1756.3522050000001, 37, 3],
#  ['Mouse in hall 3', 1759.187789, 33, 3],
#  ['Enter R2', 1759.6888059999999, 23, 2],
#  ['Quit R2', 1767.462886, 25, 2],
#  ['Enter R2', 1767.5631489999998, 23, 2],
#  ['Quit R2', 1767.597312, 25, 2],
#  ['Enter R2', 1767.629197, 23, 2],
#  ['Quit R2', 1780.345306, 25, 2],
#  ['Mouse in hall 2', 1785.9579780000001, 21, 2],
#  ['Enter R1', 1787.0588670000002, 11, 1],
#  ['Quit R1', 1809.1520899999998, 13, 1],
#  ['Mouse in hall 1', 1810.9688190000002, 9, 1],
#  ['Mouse in offer zone 4', 1811.2041980000001, 46, 4],
#  ['Enter R4', 1811.5030780000002, 47, 4],
#  ['Quit R4', 1830.1991679999999, 49, 4],
#  ['Mouse in hall 1', 1830.892813, 9, 1],
#  ['Mouse in hall 1', 1830.9577980000001, 9, 1],
#  ['Mouse in hall 1', 1831.126592, 9, 1],
#  ['Mouse in hall 1', 1831.3655420000002, 9, 1],
#  ['Mouse in hall 1', 1831.461402, 9, 1],
#  ['Mouse in hall 1', 1832.028186, 9, 1],
#  ['Mouse in hall 1', 1834.699366, 9, 1],
#  ['Mouse in hall 4', 1837.7450620000002, 45, 4],
#  ['Mouse in offer zone 3', 1838.078349, 34, 3],
#  ['Enter R3', 1838.849011, 35, 3],
#  ['Quit R3', 1847.8892420000002, 37, 3],
#  ['Mouse in hall 3', 1849.8900219999998, 33, 3],
#  ['Mouse in offer zone 2', 1850.189914, 22, 2],
#  ['Mouse in hall 3', 1850.556237, 33, 3],
#  ['Enter R2', 1850.656346, 23, 2],
#  ['Quit R2', 1874.7849469999999, 25, 2],
#  ['Mouse in hall 3', 1876.6527620000002, 33, 3],
#  ['Mouse in offer zone 3', 1881.730816, 34, 3],
#  ['Mouse in hall 3', 1882.8944379999998, 33, 3],
#  ['Enter R3', 1886.5679739999998, 35, 3],
#  ['Quit R3', 1890.975885, 37, 3],
#  ['Mouse in hall 4', 1891.2395010000002, 45, 4],
#  ['Mouse in offer zone 4', 1891.561882, 46, 4],
#  ['Enter R4', 1892.795968, 47, 4],
#  ['Quit R4', 1898.6044160000001, 49, 4],
#  ['Mouse in hall 1', 1898.6673920000003, 9, 1],
#  ['Mouse in offer zone 1', 1898.855795, 10, 1],
#  ['R1 0 offer', 1898.8563329999997, 17, 1],
#  ['Enter R1', 1899.855757, 11, 1],
#  ['Quit R1', 1901.9558530000002, 13, 1],
#  ['Mouse in hall 2', 1902.0265219999999, 21, 2],
#  ['Mouse in offer zone 2', 1902.116122, 22, 2],
#  ['R 2 0 offer', 1902.11657, 29, 2],
#  ['Enter R2', 1903.082995, 23, 2],
#  ['R 2 noreward tone', 1910.0892030000002, 27, 2],
#  ['Quit R2', 1912.561882, 25, 2],
#  ['Mouse in hall 3', 1912.660314, 33, 3],
#  ['Mouse in offer zone 3', 1912.83072, 34, 3],
#  ['R3 0 offer', 1912.831066, 41, 3],
#  ['Enter R3', 1913.564365, 35, 3],
#  ['Quit R3', 1917.4352379999998, 37, 3],
#  ['Mouse in hall 4', 1917.637107, 45, 4],
#  ['Mouse in offer zone 4', 1917.856602, 46, 4],
#  ['R4 20 offer', 1917.857037, 54, 4],
#  ['Enter R4', 1919.059776, 47, 4],
#  ['R4 noreward tone', 1924.06455, 51, 4],
#  ['Quit R4', 1929.2381699999999, 49, 4],
#  ['Mouse in hall 1', 1929.303974, 9, 1],
#  ['Mouse in offer zone 1', 1929.555968, 10, 1],
#  ['R1 20 offer', 1929.556774, 18, 1],
#  ['Enter R1', 1930.6932350000002, 11, 1],
#  ['R1 noreward tone', 1935.705766, 15, 1],
#  ['Quit R1', 1938.765197, 13, 1],
#  ['Mouse in hall 2', 1938.8727039999999, 21, 2],
#  ['Mouse in offer zone 2', 1939.0584829999998, 22, 2],
#  ['R2 100 offer', 1939.058893, 32, 2],
#  ['Enter R2', 1940.225536, 23, 2],
#  ['Servo 2 open', 1941.2336899999998, 3, 2],
#  ['R2 reward taken', 1942.537446, 28, 2],
#  ['Quit R2', 1966.3593219999998, 25, 2],
#  ['Enter R2', 1967.32425, 23, 2],
#  ['Quit R2', 1997.3932539999998, 25, 2],
#  ['Mouse in hall 3', 1997.4599039999998, 33, 3],
#  ['Mouse in offer zone 3', 1997.631706, 34, 3],
#  ['R3 20 offer', 1997.6324100000002, 42, 3],
#  ['Enter R3', 1998.427904, 35, 3],
#  ['R3 noreward tone', 2003.444019, 39, 3],
#  ['Quit R3', 2004.100416, 37, 3],
#  ['Mouse in hall 4', 2004.2672129999999, 45, 4],
#  ['Mouse in offer zone 4', 2004.4546300000002, 46, 4],
#  ['R4 20 offer', 2004.4549760000002, 54, 4],
#  ['Enter R4', 2005.2259329999997, 47, 4],
#  ['R4 noreward tone', 2010.24192, 51, 4],
#  ['Mouse in hall 1', 2013.497907, 9, 1],
#  ['Quit R4', 2014.6002429999999, 49, 4],
#  ['Mouse in hall 4', 2016.9499010000002, 45, 4],
#  ['Enter R3', 2017.5184129999998, 35, 3],
#  ['Quit R3', 2024.692531, 37, 3],
#  ['Mouse in hall 4', 2029.0628219999999, 45, 4],
#  ['Mouse in offer zone 4', 2029.985254, 46, 4],
#  ['Enter R4', 2031.7856379999998, 47, 4],
#  ['Mouse in hall 1', 2039.460877, 9, 1],
#  ['Mouse in hall 1', 2040.394816, 9, 1],
#  ['Quit R4', 2040.829146, 49, 4],
#  ['Mouse in hall 1', 2040.8624379999999, 9, 1],
#  ['Mouse in offer zone 1', 2041.11913, 10, 1],
#  ['R1 80 offer', 2041.1205120000002, 19, 1],
#  ['Enter R1', 2042.215706, 11, 1],
#  ['Servo 1 open', 2045.231014, 1, 1],
#  ['R1 reward taken', 2050.501286, 16, 1],
#  ['Quit R1', 2067.344141, 13, 1],
#  ['Mouse in hall 2', 2067.54761, 21, 2],
#  ['Mouse in offer zone 2', 2067.6736769999998, 22, 2],
#  ['R2 80 offer', 2067.6743420000003, 31, 2],
#  ['Enter R2', 2068.907136, 23, 2],
#  ['Servo 2 open', 2071.922483, 3, 2],
#  ['R2 reward taken', 2076.439398, 28, 2],
#  ['Quit R2', 2130.109274, 25, 2],
#  ['Mouse in hall 2', 2131.4848899999997, 21, 2],
#  ['Enter R1', 2131.81856, 11, 1],
#  ['Quit R1', 2137.461069, 13, 1],
#  ['Mouse in hall 1', 2138.405338, 9, 1],
#  ['Enter R4', 2138.844608, 47, 4],
#  ['Quit R4', 2151.155738, 49, 4],
#  ['Mouse in hall 4', 2151.807411, 45, 4],
#  ['Enter R3', 2152.169459, 35, 3],
#  ['Quit R3', 2155.9766019999997, 37, 3],
#  ['Mouse in hall 4', 2156.376934, 45, 4],
#  ['Mouse in offer zone 4', 2156.764032, 46, 4],
#  ['Enter R4', 2157.831962, 47, 4],
#  ['Mouse in hall 1', 2163.836787, 9, 1],
#  ['Quit R4', 2163.836992, 49, 4],
#  ['Mouse in offer zone 1', 2164.0211329999997, 10, 1],
#  ['Enter R1', 2164.859085, 11, 1],
#  ['Quit R1', 2168.926093, 13, 1],
#  ['Mouse in hall 2', 2169.463142, 21, 2],
#  ['Mouse in offer zone 2', 2170.3229309999997, 22, 2],
#  ['Enter R2', 2171.989158, 23, 2],
#  ['Quit R2', 2190.210381, 25, 2],
#  ['Mouse in hall 2', 2191.42007, 21, 2],
#  ['Enter R1', 2192.120973, 11, 1],
#  ['Quit R1', 2192.252506, 13, 1],
#  ['Enter R1', 2193.1624829999996, 11, 1],
#  ['Quit R1', 2223.022912, 13, 1],
#  ['Enter R1', 2223.089139, 11, 1],
#  ['Quit R1', 2223.691763, 13, 1],
#  ['Mouse in hall 2', 2223.9887870000002, 21, 2],
#  ['Mouse in offer zone 2', 2224.2519039999997, 22, 2],
#  ['Enter R2', 2225.617178, 23, 2],
#  ['Quit R2', 2307.980365, 25, 2],
#  ['Mouse in hall 2', 2311.055104, 21, 2],
#  ['Enter R1', 2311.723123, 11, 1],
#  ['Quit R1', 2324.836352, 13, 1],
#  ['Mouse in hall 1', 2329.65929, 9, 1],
#  ['Enter R4', 2331.162291, 47, 4],
#  ['Quit R4', 2335.062054, 49, 4],
#  ['Mouse in hall 4', 2337.248986, 45, 4],
#  ['Enter R3', 2337.753741, 35, 3],
#  ['Quit R3', 2346.126707, 37, 3],
#  ['Mouse in hall 3', 2348.690483, 33, 3],
#  ['Mouse in offer zone 2', 2349.024512, 22, 2],
#  ['Enter R2', 2349.5921789999998, 23, 2],
#  ['Quit R2', 2361.074189, 25, 2],
#  ['Enter R2', 2369.3148539999997, 23, 2],
#  ['Quit R2', 2369.783936, 25, 2],
#  ['Enter R2', 2370.98505, 23, 2],
#  ['Quit R2', 2397.285184, 25, 2],
#  ['Mouse in hall 3', 2398.514099, 33, 3],
#  ['Mouse in offer zone 3', 2398.8846719999997, 34, 3],
#  ['R3 100 offer', 2398.8852100000004, 44, 3],
#  ['Enter R3', 2399.98729, 35, 3],
#  ['Servo 3 open', 2400.996787, 5, 3],
#  ['R3 reward taken', 2402.2807420000004, 40, 3],
#  ['Quit R3', 2416.40416, 37, 3],
#  ['Mouse in hall 4', 2416.674202, 45, 4],
#  ['Mouse in offer zone 4', 2416.9879170000004, 46, 4],
#  ['R4 20 offer', 2416.9883010000003, 54, 4],
#  ['Enter R4', 2417.8881920000003, 47, 4],
#  ['R4 noreward tone', 2422.9022210000003, 51, 4],
#  ['Mouse in hall 1', 2430.969638, 9, 1],
#  ['Mouse in hall 1', 2431.1069820000002, 9, 1],
#  ['Quit R4', 2431.107264, 49, 4],
#  ['Mouse in hall 1', 2431.2056190000003, 9, 1],
#  ['Mouse in offer zone 1', 2431.458765, 10, 1],
#  ['R1 20 offer', 2431.459546, 18, 1],
#  ['Enter R1', 2432.527885, 11, 1],
#  ['R1 noreward tone', 2437.5311739999997, 15, 1],
#  ['Quit R1', 2440.544218, 13, 1],
#  ['Mouse in hall 2', 2440.637811, 21, 2],
#  ['Mouse in offer zone 2', 2440.765798, 22, 2],
#  ['R2 20 offer', 2440.767258, 30, 2],
#  ['Enter R2', 2441.898982, 23, 2],
#  ['R 2 noreward tone', 2446.916531, 27, 2],
#  ['Quit R2', 2453.046131, 25, 2],
#  ['Mouse in hall 3', 2453.145638, 33, 3],
#  ['Mouse in offer zone 3', 2453.314982, 34, 3],
#  ['R3 20 offer', 2453.315597, 42, 3],
#  ['Enter R3', 2454.080768, 35, 3],
#  ['Quit R3', 2458.819763, 37, 3],
#  ['Mouse in hall 4', 2458.95671, 45, 4],
#  ['Mouse in offer zone 4', 2459.069453, 46, 4],
#  ['R4 20 offer', 2459.06985, 54, 4],
#  ['Enter R4', 2459.870835, 47, 4],
#  ['Quit R4', 2462.4411010000003, 49, 4],
#  ['Mouse in hall 1', 2462.572134, 9, 1],
#  ['Mouse in hall 1', 2462.639002, 9, 1],
#  ['Mouse in offer zone 1', 2462.893978, 10, 1],
#  ['R1 80 offer', 2462.89472, 19, 1],
#  ['Enter R1', 2463.796954, 11, 1],
#  ['R1 noreward tone', 2466.799552, 15, 1],
#  ['Quit R1', 2470.103923, 13, 1],
#  ['Mouse in hall 2', 2470.403597, 21, 2],
#  ['Mouse in offer zone 2', 2470.530189, 22, 2],
#  ['R2 100 offer', 2470.53065, 32, 2],
#  ['Enter R2', 2471.597581, 23, 2],
#  ['Servo 2 open', 2472.599654, 3, 2],
#  ['R2 reward taken', 2475.2452989999997, 28, 2],
#  ['Quit R2', 2491.321754, 25, 2],
#  ['Mouse in hall 3', 2491.38944, 33, 3],
#  ['Mouse in offer zone 3', 2491.824998, 34, 3],
#  ['R3 100 offer', 2491.825395, 44, 3],
#  ['Mouse in hall 3', 2492.590835, 33, 3],
#  ['Enter R3', 2493.463526, 35, 3],
#  ['Quit R3', 2499.968986, 37, 3],
#  ['Mouse in hall 4', 2500.136038, 45, 4],
#  ['Mouse in offer zone 4', 2500.286336, 46, 4],
#  ['R4 20 offer', 2500.287155, 54, 4],
#  ['Enter R4', 2501.283162, 47, 4],
#  ['Quit R4', 2504.386394, 49, 4],
#  ['Mouse in hall 1', 2504.5195519999997, 9, 1],
#  ['Mouse in offer zone 1', 2504.842957, 10, 1],
#  ['R1 0 offer', 2504.843584, 17, 1],
#  ['Mouse in hall 2', 2506.378419, 21, 2],
#  ['Mouse in offer zone 2', 2506.6067329999996, 22, 2],
#  ['R2 20 offer', 2506.607462, 30, 2],
#  ['Enter R2', 2507.5765890000002, 23, 2],
#  ['Quit R2', 2511.47735, 25, 2],
#  ['Mouse in hall 3', 2511.509658, 33, 3],
#  ['Mouse in offer zone 3', 2511.646874, 34, 3],
#  ['R3 100 offer', 2511.647322, 44, 3],
#  ['Enter R3', 2512.583117, 35, 3],
#  ['Servo 3 open', 2513.585728, 5, 3],
#  ['R3 reward taken', 2514.93079, 40, 3],
#  ['Quit R3', 2528.867162, 37, 3],
#  ['Mouse in hall 4', 2528.968576, 45, 4],
#  ['Mouse in offer zone 4', 2529.148698, 46, 4],
#  ['R4 0 offer', 2529.14903, 53, 4],
#  ['Enter R4', 2530.050291, 47, 4],
#  ['Quit R4', 2535.225024, 49, 4],
#  ['Mouse in hall 1', 2536.860198, 9, 1],
#  ['Mouse in hall 4', 2539.915059, 45, 4],
#  ['Enter R3', 2540.479667, 35, 3],
#  ['Quit R3', 2545.85248, 37, 3],
#  ['Mouse in hall 4', 2546.188326, 45, 4],
#  ['Mouse in offer zone 4', 2546.5396739999996, 46, 4],
#  ['Mouse in hall 1', 2547.868454, 9, 1],
#  ['Mouse in offer zone 1', 2548.0953219999997, 10, 1],
#  ['R1 0 offer', 2548.096589, 17, 1],
#  ['Mouse in hall 2', 2549.592371, 21, 2],
#  ['Mouse in offer zone 2', 2549.753894, 22, 2],
#  ['R2 80 offer', 2549.754266, 31, 2],
#  ['Enter R2', 2550.7956480000003, 23, 2],
#  ['Servo 2 open', 2553.798464, 3, 2],
#  ['R2 reward taken', 2555.419328, 28, 2],
#  ['Quit R2', 2571.848166, 25, 2],
#  ['Mouse in hall 3', 2572.114829, 33, 3],
#  ['Mouse in offer zone 3', 2572.5524219999998, 34, 3],
#  ['R3 20 offer', 2572.55328, 42, 3],
#  ['Enter R3', 2573.520461, 35, 3],
#  ['Quit R3', 2577.825114, 37, 3],
#  ['Mouse in hall 4', 2577.9554940000003, 45, 4],
#  ['Mouse in offer zone 4', 2578.104371, 46, 4],
#  ['R4 80 offer', 2578.10473, 55, 4],
#  ['Enter R4', 2579.040013, 47, 4],
#  ['Servo 4 open', 2582.050419, 7, 4],
#  ['R4 reward taken', 2583.5735809999996, 52, 4],
#  ['Quit R4', 2592.688256, 49, 4],
#  ['Mouse in hall 1', 2592.756058, 9, 1],
#  ['Mouse in hall 1', 2592.82185, 9, 1],
#  ['Mouse in offer zone 1', 2593.14304, 10, 1],
#  ['R1 80 offer', 2593.143962, 19, 1],
#  ['Enter R1', 2594.477069, 11, 1],
#  ['Servo 1 open', 2597.488256, 1, 1],
#  ['R1 reward taken', 2600.606298, 16, 1],
#  ['Quit R1', 2625.4495100000004, 13, 1],
#  ['Mouse in hall 2', 2625.615539, 21, 2],
#  ['Mouse in offer zone 2', 2625.70935, 22, 2],
#  ['R2 20 offer', 2625.70999, 30, 2],
#  ['Enter R2', 2626.874406, 23, 2],
#  ['R 2 noreward tone', 2631.882778, 27, 2],
#  ['Quit R2', 2639.992346, 25, 2],
#  ['Mouse in hall 3', 2640.092275, 33, 3],
#  ['Mouse in offer zone 3', 2640.329357, 34, 3],
#  ['R3 100 offer', 2640.330061, 44, 3],
#  ['Enter R3', 2641.72855, 35, 3],
#  ['Servo 3 open', 2642.730982, 5, 3],
#  ['R3 reward taken', 2644.343104, 40, 3],
#  ['Quit R3', 2668.59433, 37, 3],
#  ['Enter R3', 2673.301133, 35, 3],
#  ['Quit R3', 2676.103424, 37, 3],
#  ['Enter R3', 2676.569536, 35, 3],
#  ['Quit R3', 2680.6416510000004, 37, 3],
#  ['Mouse in hall 4', 2680.8412670000002, 45, 4],
#  ['Mouse in offer zone 4', 2680.9636219999998, 46, 4],
#  ['R4 20 offer', 2680.964429, 54, 4],
#  ['Enter R4', 2681.820032, 47, 4],
#  ['R4 noreward tone', 2686.823398, 51, 4],
#  ['Quit R4', 2694.669504, 49, 4],
#  ['Mouse in hall 4', 2696.457805, 45, 4],
#  ['Enter R3', 2696.891187, 35, 3],
#  ['Quit R3', 2700.196058, 37, 3],
#  ['Mouse in hall 3', 2700.959437, 33, 3],
#  ['Enter R2', 2701.496922, 23, 2],
#  ['Quit R2', 2718.111718, 25, 2],
#  ['Enter R2', 2718.178394, 23, 2],
#  ['Quit R2', 2718.245658, 25, 2],
#  ['Enter R2', 2718.279078, 23, 2],
#  ['Quit R2', 2718.3121539999997, 25, 2],
#  ['Mouse in hall 3', 2719.280051, 33, 3],
#  ['Mouse in offer zone 3', 2719.522509, 34, 3],
#  ['Enter R3', 2720.388992, 35, 3],
#  ['Quit R3', 2721.822579, 37, 3],
#  ['Mouse in hall 4', 2721.924378, 45, 4],
#  ['Mouse in offer zone 4', 2722.066189, 46, 4],
#  ['Enter R4', 2722.867162, 47, 4],
#  ['Quit R4', 2724.4046719999997, 49, 4],
#  ['Mouse in hall 1', 2724.438298, 9, 1],
#  ['Mouse in offer zone 1', 2724.6307070000003, 10, 1],
#  ['R1 0 offer', 2724.631411, 17, 1],
#  ['Mouse in hall 2', 2725.932787, 21, 2],
#  ['Mouse in offer zone 2', 2726.05481, 22, 2],
#  ['R2 20 offer', 2726.055296, 30, 2],
#  ['Enter R2', 2727.061184, 23, 2],
#  ['R 2 noreward tone', 2732.080704, 27, 2],
#  ['Quit R2', 2740.473702, 25, 2],
#  ['Mouse in hall 3', 2740.60713, 33, 3],
#  ['Mouse in offer zone 3', 2740.774656, 34, 3],
#  ['R3 100 offer', 2740.7752960000003, 44, 3],
#  ['Enter R3', 2741.675251, 35, 3],
#  ['Servo 3 open', 2742.6769280000003, 5, 3],
#  ['R3 reward taken', 2743.807066, 40, 3],
#  ['Quit R3', 2761.3980030000002, 37, 3],
#  ['Mouse in hall 4', 2761.497946, 45, 4],
#  ['Mouse in offer zone 4', 2761.8449539999997, 46, 4],
#  ['R4 0 offer', 2761.845325, 53, 4],
#  ['Enter R4', 2762.749542, 47, 4],
#  ['R4 noreward tone', 2769.765594, 51, 4],
#  ['Quit R4', 2772.426253, 49, 4],
#  ['Mouse in hall 4', 2774.316851, 45, 4],
#  ['Enter R3', 2775.2163579999997, 35, 3],
#  ['Quit R3', 2785.629312, 37, 3],
#  ['Mouse in hall 3', 2793.764902, 33, 3],
#  ['Enter R2', 2795.533786, 23, 2],
#  ['Quit R2', 2807.647616, 25, 2],
#  ['Enter R2', 2810.519258, 23, 2],
#  ['Quit R2', 2811.68727, 25, 2],
#  ['Enter R2', 2811.720013, 23, 2],
#  ['Quit R2', 2815.8897920000004, 25, 2],
#  ['Mouse in hall 2', 2817.569242, 21, 2],
#  ['Enter R1', 2818.032653, 11, 1],
#  ['Quit R1', 2830.885734, 13, 1],
#  ['Enter R1', 2831.017882, 11, 1],
#  ['Quit R1', 2831.050918, 13, 1],
#  ['Enter R1', 2831.348454, 11, 1],
#  ['Quit R1', 2831.688307, 13, 1],
#  ['Enter R1', 2831.7250559999998, 11, 1],
#  ['Quit R1', 2834.936819, 13, 1],
#  ['Mouse in hall 1', 2837.500608, 9, 1],
#  ['Mouse in offer zone 4', 2837.868173, 46, 4],
#  ['Enter R4', 2838.3667969999997, 47, 4],
#  ['Quit R4', 2842.5696, 49, 4],
#  ['Mouse in hall 4', 2843.325773, 45, 4],
#  ['Mouse in offer zone 3', 2843.491622, 34, 3],
#  ['Enter R3', 2843.927386, 35, 3],
#  ['Quit R3', 2848.997619, 37, 3],
#  ['Enter R3', 2856.80713, 35, 3],
#  ['Quit R3', 2857.14112, 37, 3],
#  ['Enter R3', 2857.174221, 35, 3],
#  ['Quit R3', 2857.4416260000003, 37, 3],
#  ['Mouse in hall 4', 2857.841446, 45, 4],
#  ['Mouse in offer zone 4', 2858.3251579999996, 46, 4],
#  ['Enter R4', 2859.7883899999997, 47, 4],
#  ['Quit R4', 2862.694259, 49, 4],
#  ['Enter R4', 2880.713766, 47, 4],
#  ['Quit R4', 2885.986342, 49, 4],
#  ['Mouse in hall 1', 2887.15424, 9, 1],
#  ['Mouse in offer zone 1', 2887.345843, 10, 1],
#  ['R1 80 offer', 2887.346317, 19, 1],
#  ['Enter R1', 2888.314189, 11, 1],
#  ['Servo 1 open', 2891.3209469999997, 1, 1],
#  ['R1 reward taken', 2892.636173, 16, 1],
#  ['Quit R1', 2910.271322, 13, 1],
#  ['Mouse in hall 2', 2910.840256, 21, 2],
#  ['Mouse in offer zone 2', 2911.066867, 22, 2],
#  ['R 2 0 offer', 2911.0673920000004, 29, 2],
#  ['Enter R2', 2912.502963, 23, 2],
#  ['R 2 noreward tone', 2919.512154, 27, 2],
#  ['Quit R2', 2921.643891, 25, 2],
#  ['Mouse in hall 2', 2922.889882, 21, 2],
#  ['Enter R1', 2923.18505, 11, 1],
#  ['Quit R1', 2951.425792, 13, 1],
#  ['Enter R1', 2951.523405, 11, 1],
#  ['Quit R1', 2951.686861, 13, 1],
#  ['Enter R1', 2951.785139, 11, 1],
#  ['Quit R1', 2962.2368260000003, 13, 1],
#  ['Mouse in hall 1', 2963.8728579999997, 9, 1],
#  ['Enter R4', 2964.306829, 47, 4],
#  ['Quit R4', 2975.686093, 49, 4],
#  ['Mouse in hall 1', 2975.852672, 9, 1],
#  ['Mouse in hall 1', 2975.986432, 9, 1],
#  ['Mouse in hall 1', 2976.3204100000003, 9, 1],
#  ['Mouse in hall 1', 2976.453325, 9, 1],
#  ['Mouse in hall 1', 2976.553856, 9, 1],
#  ['Mouse in hall 1', 2976.720499, 9, 1],
#  ['Mouse in hall 1', 2976.854413, 9, 1],
#  ['Mouse in hall 1', 2977.188186, 9, 1],
#  ['Mouse in hall 1', 2977.290125, 9, 1],
#  ['Mouse in hall 1', 2977.492173, 9, 1],
#  ['Mouse in hall 1', 2977.561664, 9, 1],
#  ['Mouse in hall 1', 2977.7260929999998, 9, 1],
#  ['Mouse in hall 1', 2977.825562, 9, 1],
#  ['Mouse in hall 1', 2977.958669, 9, 1],
#  ['Mouse in hall 1', 2978.021978, 9, 1],
#  ['Mouse in hall 1', 2978.356147, 9, 1],
#  ['Mouse in hall 1', 2978.58912, 9, 1],
#  ['Mouse in hall 1', 2978.6567809999997, 9, 1],
#  ['Mouse in hall 1', 2978.722918, 9, 1],
#  ['Enter R4', 2978.78953, 47, 4],
#  ['Mouse in hall 1', 2978.8228480000002, 9, 1],
#  ['Quit R4', 2978.822963, 49, 4],
#  ['Enter R4', 2978.856307, 47, 4],
#  ['Quit R4', 2978.923136, 49, 4],
#  ['Enter R4', 2979.257165, 47, 4],
#  ['Quit R4', 2979.657114, 49, 4],
#  ['Enter R4', 2979.690662, 47, 4],
#  ['Mouse in hall 1', 2979.79081, 9, 1],
#  ['Quit R4', 2979.924595, 49, 4],
#  ['Enter R4', 2979.957325, 47, 4],
#  ['Quit R4', 2979.9909629999997, 49, 4],
#  ['Enter R4', 2980.024512, 47, 4],
#  ['Quit R4', 2980.058176, 49, 4],
#  ['Enter R4', 2980.091277, 47, 4],
#  ['Quit R4', 2980.161536, 49, 4],
#  ['Mouse in hall 1', 2980.1950460000003, 9, 1],
#  ['Enter R4', 2980.1953280000002, 47, 4],
#  ['Quit R4', 2980.260877, 49, 4],
#  ['Enter R4', 2980.46121, 47, 4],
#  ['Mouse in hall 1', 2980.495539, 9, 1],
#  ['Quit R4', 2980.495834, 49, 4],
#  ['Mouse in hall 1', 2980.894566, 9, 1],
#  ['Mouse in hall 1', 2981.09728, 9, 1],
#  ['Enter R4', 2982.199219, 47, 4],
#  ['Quit R4', 2982.467853, 49, 4],
#  ['Mouse in hall 4', 2985.953869, 45, 4],
#  ['Enter R3', 2986.521318, 35, 3],
#  ['Quit R3', 2993.763277, 37, 3],
#  ['Mouse in hall 3', 3000.240307, 33, 3],
#  ['Mouse in offer zone 2', 3000.468864, 22, 2],
#  ['Enter R2', 3000.871782, 23, 2],
#  ['Quit R2', 3006.607936, 25, 2],
#  ['Mouse in hall 3', 3007.0750980000003, 33, 3],
#  ['Mouse in offer zone 3', 3007.579712, 34, 3],
#  ['R3 20 offer', 3007.58016, 42, 3],
#  ['Enter R3', 3009.080589, 35, 3],
#  ['R3 noreward tone', 3014.095232, 39, 3],
#  ['Quit R3', 3018.791232, 37, 3],
#  ['Mouse in hall 4', 3018.924659, 45, 4],
#  ['Mouse in offer zone 4', 3019.07296, 46, 4],
#  ['R4 20 offer', 3019.0736899999997, 54, 4],
#  ['Enter R4', 3019.97175, 47, 4],
#  ['Servo 4 open', 3024.9792899999998, 7, 4],
#  ['R4 reward taken', 3026.5794690000002, 52, 4],
#  ['Quit R4', 3045.565632, 49, 4],
#  ['Mouse in hall 1', 3045.6320769999998, 9, 1],
#  ['Mouse in hall 1', 3045.739021, 9, 1],
#  ['Mouse in hall 1', 3045.803187, 9, 1],
#  ['Mouse in hall 1', 3046.037248, 9, 1],
#  ['Mouse in hall 1', 3046.166093, 9, 1],
#  ['Mouse in hall 1', 3046.268582, 9, 1],
#  ['Mouse in hall 1', 3046.533082, 9, 1],
#  ['Mouse in hall 1', 3046.8382079999997, 9, 1],
#  ['Mouse in hall 1', 3047.06935, 9, 1],
#  ['Mouse in hall 1', 3047.5738109999998, 9, 1],
#  ['Mouse in hall 1', 3049.371802, 9, 1],
#  ['Mouse in offer zone 1', 3049.830144, 10, 1],
#  ['R1 0 offer', 3049.830554, 17, 1],
#  ['Enter R1', 3050.964941, 11, 1],
#  ['Quit R1', 3056.8382460000003, 13, 1],
#  ['Mouse in hall 2', 3057.071629, 21, 2],
#  ['Mouse in offer zone 2', 3057.432294, 22, 2],
#  ['R2 100 offer', 3057.432845, 32, 2],
#  ['Enter R2', 3058.873728, 23, 2],
#  ['Servo 2 open', 3059.8916480000003, 3, 2],
#  ['R2 reward taken', 3061.205888, 28, 2],
#  ['Quit R2', 3073.157184, 25, 2],
#  ['Mouse in hall 3', 3074.151027, 33, 3],
#  ['Mouse in hall 3', 3074.2510460000003, 33, 3],
#  ['Enter R2', 3074.7555199999997, 23, 2],
#  ['Mouse in hall 3', 3074.885427, 33, 3],
#  ['Quit R2', 3078.523354, 25, 2],
#  ['Enter R2', 3078.5562370000002, 23, 2],
#  ['Quit R2', 3078.5900030000003, 25, 2],
#  ['Enter R2', 3098.145101, 23, 2],
#  ['Quit R2', 3106.322445, 25, 2],
#  ['Mouse in hall 3', 3106.389901, 33, 3],
#  ['Mouse in offer zone 3', 3106.8260219999997, 34, 3],
#  ['R3 100 offer', 3106.8263420000003, 44, 3],
#  ['Enter R3', 3108.227494, 35, 3],
#  ['Servo 3 open', 3109.229286, 5, 3],
#  ['R3 reward taken', 3113.713139, 40, 3],
#  ['Quit R3', 3143.835622, 37, 3],
#  ['Mouse in hall 4', 3144.0004480000002, 45, 4],
#  ['Mouse in offer zone 4', 3144.179584, 46, 4],
#  ['R4 0 offer', 3144.180173, 53, 4],
#  ['Enter R4', 3145.0441339999998, 47, 4],
#  ['R4 noreward tone', 3152.0557440000002, 51, 4],
#  ['Mouse in hall 1', 3158.793318, 9, 1],
#  ['Quit R4', 3158.7934210000003, 49, 4],
#  ['Mouse in offer zone 1', 3158.921216, 10, 1],
#  ['R1 80 offer', 3158.922099, 19, 1],
#  ['Enter R1', 3159.821491, 11, 1],
#  ['Servo 1 open', 3162.823552, 1, 1],
#  ['R1 reward taken', 3164.069594, 16, 1],
#  ['Quit R1', 3181.084634, 13, 1],
#  ['Mouse in hall 2', 3181.279616, 21, 2],
#  ['Mouse in offer zone 2', 3181.407386, 22, 2],
#  ['R2 20 offer', 3181.4078210000002, 30, 2],
#  ['Enter R2', 3182.6777859999997, 23, 2],
#  ['R 2 noreward tone', 3187.696371, 27, 2],
#  ['Quit R2', 3192.5858940000003, 25, 2],
#  ['Mouse in hall 3', 3192.7869570000003, 33, 3],
#  ['Mouse in offer zone 3', 3193.126234, 34, 3],
#  ['R3 0 offer', 3193.127014, 41, 3],
#  ['Enter R3', 3193.9987969999997, 35, 3],
#  ['Quit R3', 3198.064781, 37, 3],
#  ['Mouse in hall 4', 3198.264666, 45, 4],
#  ['Mouse in offer zone 4', 3198.407949, 46, 4],
#  ['R4 0 offer', 3198.408768, 53, 4],
#  ['Enter R4', 3199.343898, 47, 4],
#  ['Mouse in hall 1', 3205.749376, 9, 1],
#  ['Quit R4', 3205.74953, 49, 4],
#  ['Mouse in offer zone 1', 3205.943667, 10, 1],
#  ['R1 20 offer', 3205.944858, 18, 1],
#  ['Enter R1', 3206.94295, 11, 1],
#  ['Quit R1', 3207.242586, 13, 1],
#  ['Enter R1', 3207.476544, 11, 1],
#  ['Quit R1', 3210.41257, 13, 1],
#  ['Mouse in hall 2', 3210.5464699999998, 21, 2],
#  ['Mouse in offer zone 2', 3210.640269, 22, 2],
#  ['R2 20 offer', 3210.640742, 30, 2],
#  ['Enter R2', 3211.679718, 23, 2],
#  ['Quit R2', 3216.580083, 25, 2],
#  ['Mouse in hall 3', 3216.646707, 33, 3],
#  ['Mouse in offer zone 3', 3216.785293, 34, 3],
#  ['R3 80 offer', 3216.7856899999997, 43, 3],
#  ['Enter R3', 3217.989645, 35, 3],
#  ['Servo 3 open', 3221.00288, 5, 3],
#  ['R3 reward taken', 3222.565837, 40, 3],
#  ['Quit R3', 3234.742067, 37, 3],
#  ['Mouse in hall 4', 3234.939738, 45, 4],
#  ['Mouse in offer zone 4', 3235.1182719999997, 46, 4],
#  ['R4 20 offer', 3235.118848, 54, 4],
#  ['Enter R4', 3236.3173890000003, 47, 4],
#  ['R4 noreward tone', 3241.3335420000003, 51, 4],
#  ['Quit R4', 3244.59072, 49, 4],
#  ['Mouse in hall 1', 3244.624064, 9, 1],
#  ['Mouse in offer zone 1', 3244.884928, 10, 1],
#  ['R1 20 offer', 3244.885888, 18, 1],
#  ['Enter R1', 3245.9201789999997, 11, 1],
#  ['R1 noreward tone', 3250.9336829999997, 15, 1],
#  ['Quit R1', 3253.828557, 13, 1],
#  ['Mouse in hall 2', 3253.996723, 21, 2],
#  ['Mouse in offer zone 2', 3254.2918019999997, 22, 2],
#  ['R 2 0 offer', 3254.292262, 29, 2],
#  ['Mouse in hall 3', 3255.457907, 33, 3],
#  ['Mouse in offer zone 3', 3255.728973, 34, 3],
#  ['R3 100 offer', 3255.729472, 44, 3],
#  ['Enter R3', 3256.963494, 35, 3],
#  ['Servo 3 open', 3257.96544, 5, 3],
#  ['R3 reward taken', 3259.248666, 40, 3],
#  ['Quit R3', 3281.663194, 37, 3],
#  ['Mouse in hall 4', 3281.794432, 45, 4],
#  ['Mouse in offer zone 4', 3281.971354, 46, 4],
#  ['R4 20 offer', 3281.971955, 54, 4],
#  ['Enter R4', 3282.870157, 47, 4],
#  ['R4 noreward tone', 3287.886989, 51, 4],
#  ['Quit R4', 3291.879526, 49, 4],
#  ['Mouse in hall 1', 3291.913485, 9, 1],
#  ['Mouse in offer zone 1', 3292.074662, 10, 1],
#  ['R1 80 offer', 3292.075763, 19, 1],
#  ['Enter R1', 3293.073229, 11, 1],
#  ['Servo 1 open', 3296.090419, 1, 1],
#  ['R1 reward taken', 3297.431411, 16, 1],
#  ['Quit R1', 3308.1932420000003, 13, 1],
#  ['Mouse in hall 2', 3308.39337, 21, 2],
#  ['Mouse in offer zone 2', 3308.558643, 22, 2],
#  ['R2 80 offer', 3308.561574, 31, 2],
#  ['Enter R2', 3309.852774, 23, 2],
#  ['R 2 noreward tone', 3312.868186, 27, 2],
#  ['Quit R2', 3319.1338370000003, 25, 2],
#  ['Mouse in hall 3', 3319.399974, 33, 3],
#  ['Mouse in hall 3', 3319.764211, 33, 3],
#  ['Mouse in offer zone 3', 3319.968947, 34, 3],
#  ['R3 0 offer', 3319.969446, 41, 3],
#  ['Enter R3', 3320.8414980000002, 35, 3],
#  ['Quit R3', 3322.472384, 37, 3],
#  ['Mouse in hall 4', 3322.605376, 45, 4],
#  ['Mouse in offer zone 4', 3322.746509, 46, 4],
#  ['R4 100 offer', 3322.746918, 56, 4],
#  ['Enter R4', 3323.681293, 47, 4],
#  ['Servo 4 open', 3324.684774, 7, 4],
#  ['R4 reward taken', 3326.080986, 52, 4],
#  ['Mouse in hall 1', 3333.3935739999997, 9, 1],
#  ['Mouse in hall 1', 3341.63753, 9, 1],
#  ['Mouse in hall 1', 3341.70537, 9, 1],
#  ['Mouse in hall 1', 3341.837171, 9, 1],
#  ['Mouse in hall 1', 3342.06793, 9, 1],
#  ['Mouse in hall 1', 3342.202688, 9, 1],
#  ['Mouse in hall 1', 3343.269312, 9, 1],
#  ['Quit R4', 3345.441664, 49, 4],
#  ['Mouse in hall 1', 3347.9794690000003, 9, 1],
#  ['Mouse in hall 4', 3349.372032, 45, 4],
#  ['Mouse in hall 4', 3351.10528, 45, 4],
#  ['Mouse in hall 3', 3360.380096, 33, 3],
#  ['Enter R2', 3361.414579, 23, 2],
#  ['Quit R2', 3368.289267, 25, 2],
#  ['Enter R2', 3368.356224, 23, 2],
#  ['Quit R2', 3368.5242369999996, 25, 2],
#  ['Enter R2', 3368.5558020000003, 23, 2],
#  ['Quit R2', 3369.7260420000002, 25, 2],
#  ['Enter R2', 3369.788083, 23, 2],
#  ['Quit R2', 3373.6926340000005, 25, 2],
#  ['Mouse in hall 3', 3375.296768, 33, 3],
#  ['Mouse in offer zone 3', 3376.269133, 34, 3],
#  ['Mouse in hall 3', 3376.6660479999996, 33, 3],
#  ['Enter R3', 3379.1690369999997, 35, 3],
#  ['Quit R3', 3384.620531, 37, 3],
#  ['Mouse in hall 3', 3396.5857409999994, 33, 3],
#  ['Mouse in hall 3', 3400.7592189999996, 33, 3],
#  ['Mouse in hall 3', 3400.927078, 33, 3],
#  ['Mouse in hall 3', 3401.023565, 33, 3],
#  ['Enter R2', 3411.381542, 23, 2],
#  ['Mouse in hall 3', 3411.406822, 33, 3],
#  ['Quit R2', 3417.845056, 25, 2],
#  ['Enter R2', 3417.87785, 23, 2],
#  ['Quit R2', 3418.346074, 25, 2],
#  ['Mouse in hall 3', 3418.7808, 33, 3],
#  ['Mouse in offer zone 3', 3419.0818689999996, 34, 3],
#  ['Mouse in hall 4', 3420.319347, 45, 4],
#  ...]

# %%
def detect_keyword_in_event(events_list):
    """
    event -- List: list of bonsai events
    """
    def detect_keyword(string):
        keyword = None
        if string.__contains__('hall'):
            keyword = 'hall'
        elif string.__contains__('zone'):
            keyword = 'offer zone'
        elif string.__contains__('offer'):
            probability = re.findall('[0-9]+', string)[1]
            keyword = probability + '_offer'
        elif string.__contains__('enter'):
            keyword = 'enter'
        elif string.__contains__('Quit'):
            keyword = 'quit'
        elif string.__contains__('noreward'):
            keyword = 'noreward'
        elif string.__contains__('taken'):
            keyword = 'taken'
        elif string.__contains__('servo'):
            keyword = 'servo'
        elif string.__contains__('Enter'):
            keyword = 'enter'
        elif string.__contains__('Reject'):
            keyword = 'reject'
        return keyword
    new_events_list = []
    for i in events_list:
        if len(i) < 5:
            i_description = i[0]
            i += [detect_keyword(i_description)]
            new_events_list.append(i)
        else:
            new_events_list.append(i)
    return new_events_list
        
events_list_with_keyword = detect_keyword_in_event(events_list)
events_list_with_keyword[:50]
# Out:
# [['Mouse in offer zone 1', 246.80968959999998, 10, 1, 'offer zone'],
#  ['R1 100 offer', 247.0, 20, 1, '100_offer'],
#  ['Enter R1', 247.0, 11, 1, 'enter'],
#  ['Quit R1', 252.716992, 13, 1, 'quit'],
#  ['Mouse in hall 2', 253.3837312, 21, 2, 'hall'],
#  ['Mouse in offer zone 2', 253.5054336, 22, 2, 'offer zone'],
#  ['R 2 0 offer', 253.51754240000002, 29, 2, '0_offer'],
#  ['Enter R2', 255.90618880000002, 23, 2, 'enter'],
#  ['R 2 noreward tone', 262.972096, 27, 2, 'noreward'],
#  ['Quit R2', 363.43120639999995, 25, 2, 'quit'],
#  ['Mouse in hall 3', 363.49783039999994, 33, 3, 'hall'],
#  ['Mouse in offer zone 3', 365.9704832, 34, 3, 'offer zone'],
#  ['R3 0 offer', 365.98688, 41, 3, '0_offer'],
#  ['Enter R3', 367.67199999999997, 35, 3, 'enter'],
#  ['R3 noreward tone', 374.7444992, 39, 3, 'noreward'],
#  ['Quit R3', 414.3253376, 37, 3, 'quit'],
#  ['Mouse in hall 4', 414.49186560000004, 45, 4, 'hall'],
#  ['Mouse in offer zone 4', 414.62776319999995, 46, 4, 'offer zone'],
#  ['R4 0 offer', 414.6416512, 53, 4, '0_offer'],
#  ['Enter R4', 416.5275648, 47, 4, 'enter'],
#  ['R4 noreward tone', 423.6059648, 51, 4, 'noreward'],
#  ['Quit R4', 426.1719552, 49, 4, 'quit'],
#  ['Mouse in hall 1', 426.6690688, 9, 1, 'hall'],
#  ['Mouse in hall 1', 428.77493760000004, 9, 1, 'hall'],
#  ['Mouse in offer zone 1', 429.882496, 10, 1, 'offer zone'],
#  ['R1 20 offer', 429.885568, 18, 1, '20_offer'],
#  ['Enter R1', 431.483712, 11, 1, 'enter'],
#  ['R1 noreward tone', 436.53208319999993, 15, 1, 'noreward'],
#  ['Quit R1', 520.4531968, 13, 1, 'quit'],
#  ['Mouse in hall 2', 520.5879808, 21, 2, 'hall'],
#  ['Mouse in offer zone 2', 520.909952, 22, 2, 'offer zone'],
#  ['R2 20 offer', 520.9168639999999, 30, 2, '20_offer'],
#  ['Enter R2', 522.8465536, 23, 2, 'enter'],
#  ['R 2 noreward tone', 527.8572416000001, 27, 2, 'noreward'],
#  ['Quit R2', 611.2837503999999, 25, 2, 'quit'],
#  ['Mouse in hall 2', 613.4583167999999, 21, 2, 'hall'],
#  ['Enter R1', 614.0576512, 11, 1, 'enter'],
#  ['Quit R1', 623.3758207999999, 13, 1, 'quit'],
#  ['Mouse in hall 1', 624.7597440000001, 9, 1, 'hall'],
#  ['Enter R4', 627.3678976, 47, 4, 'enter'],
#  ['Quit R4', 639.2768127999999, 49, 4, 'quit'],
#  ['Enter R4', 639.3104128, 47, 4, 'enter'],
#  ['Quit R4', 639.3435776, 49, 4, 'quit'],
#  ['Mouse in hall 4', 642.2147456, 45, 4, 'hall'],
#  ['Enter R3', 642.6813952, 35, 3, 'enter'],
#  ['Quit R3', 654.0993152000001, 37, 3, 'quit'],
#  ['Mouse in hall 3', 656.3304063999999, 33, 3, 'hall'],
#  ['Mouse in offer zone 2', 656.4654336, 22, 2, 'offer zone'],
#  ['Enter R2', 656.6965376, 23, 2, 'enter'],
#  ['Quit R2', 665.4728064, 25, 2, 'quit']]

# %%
import copy


class DoublyLinkedList:
    """A doubly linked list data structure"""
    def __init__(self):
        self.sentinel = Event_Node()
        self.sentinel.next = None
        self.sentinel.prev = None
        self.size = 0

    def write_dataFrame(self):
        assert self.sentinel.next is not None
        n = self.sentinel.next
        list_of_objects = []
        while n is not None:
            list_of_objects.append(n.current)
            n = n.next
        dataFrame = pd.DataFrame([obj.__dict__ for obj in list_of_objects])
        dataFrame = dataFrame.drop(columns=['item', 'prev', 'next'])
        return dataFrame
    
    def add_first(self, item):
        new_item = copy.deepcopy(item)
        new_item.next = None
        new_item.prev = None
        self.sentinel.next = new_item
        self.sentinel.prev = new_item
        self.size += 1

    def add_to_end(self, item):
        if self.size == 0:
            self.add_first(item)
            return
        new_last = copy.deepcopy(item)
        new_last.next = None
        new_last.prev = None
        self.sentinel.prev.next = new_last
        self.sentinel.prev = new_last
        self.size += 1

    def add_to_start(self, item):
        if size == 0:
            self.add_first(item)
            return
        new_last = copy.deepcopy(item)
        new_last.next = None
        new_last.prev = None
        self.sentinel.next.prev = new_last
        self.sentinel.next = new_last
        self.size += 1

# %%
class Event_Node:
    def __init__(self):
        self.current = None
        self.prev = None
        self.next = None

class BonsaiEvent(Event_Node):
    def __init__(self, event):
        self.item = event  # The bonsai_event object itself
        self.event_description = event[0]
        self.timestamp = event[1]
        self.event_code = event[2]
        self.restaurant = event[3]
        self.keyword = event[4]
        self.current = self


class Trial(Event_Node):
    """
    Series of bonsai events in the same restaurant stored as
    a doubly linked list
    """

    def __init__(self, dll_of_bonsaievents, index):
        """
        events -- DLL: list of bonsai_event objects
        """
        self.valid = False  # True: Valid Trial
        self.tone_prob = None
        self.restaurant = None
        self.choice = None
        self.negotiation = None
        self.collection = None
        self.index = index
        self.item = dll_of_bonsaievents
        self.current = self


class Lap(Event_Node):
    """A doubly linked list of trials"""

    def __init__(self, dll_of_trials, direction, index):
        self.direction = direction
        self.index = index
        self.total_trial_count = dll_of_trials.size
        self.valid_trial_count = None
        self.item = dll_of_trials
        self.current = self


class Session:
    """A doubly linked list of laps"""

    def __init__(self, dll_of_laps):
        self.lap_count = dll_of_laps.size
        self.valid_trial_count

# %%
list_of_bonsaievents = DoublyLinkedList()
for i in events_list[:40]:
    event_object = BonsaiEvent(i)
    list_of_bonsaievents.add_to_end(event_object)
list_of_bonsaievents.write_dataFrame()
# Out:
#         event_description   timestamp  event_code  restaurant     keyword  \
# 0   Mouse in offer zone 1  246.809690          10           1  offer zone
# 1            R1 100 offer  247.000000          20           1   100_offer
# 2                Enter R1  247.000000          11           1       enter
# 3                 Quit R1  252.716992          13           1        quit
# 4         Mouse in hall 2  253.383731          21           2        hall
# 5   Mouse in offer zone 2  253.505434          22           2  offer zone
# 6             R 2 0 offer  253.517542          29           2     0_offer
# 7                Enter R2  255.906189          23           2       enter
# 8       R 2 noreward tone  262.972096          27           2    noreward
# 9                 Quit R2  363.431206          25           2        quit
# 10        Mouse in hall 3  363.497830          33           3        hall
# 11  Mouse in offer zone 3  365.970483          34           3  offer zone
# 12             R3 0 offer  365.986880          41           3     0_offer
# 13               Enter R3  367.672000          35           3       enter
# 14       R3 noreward tone  374.744499          39           3    noreward
# 15                Quit R3  414.325338          37           3        quit
# 16        Mouse in hall 4  414.491866          45           4        hall
# 17  Mouse in offer zone 4  414.627763          46           4  offer zone
# 18             R4 0 offer  414.641651          53           4     0_offer
# 19               Enter R4  416.527565          47           4       enter
# 20       R4 noreward tone  423.605965          51           4    noreward
# 21                Quit R4  426.171955          49           4        quit
# 22        Mouse in hall 1  426.669069           9           1        hall
# 23        Mouse in hall 1  428.774938           9           1        hall
# 24  Mouse in offer zone 1  429.882496          10           1  offer zone
# 25            R1 20 offer  429.885568          18           1    20_offer
# 26               Enter R1  431.483712          11           1       enter
# 27       R1 noreward tone  436.532083          15           1    noreward
# 28                Quit R1  520.453197          13           1        quit
# 29        Mouse in hall 2  520.587981          21           2        hall
# 30  Mouse in offer zone 2  520.909952          22           2  offer zone
# 31            R2 20 offer  520.916864          30           2    20_offer
# 32               Enter R2  522.846554          23           2       enter
# 33      R 2 noreward tone  527.857242          27           2    noreward
# 34                Quit R2  611.283750          25           2        quit
# 35        Mouse in hall 2  613.458317          21           2        hall
# 36               Enter R1  614.057651          11           1       enter
# 37                Quit R1  623.375821          13           1        quit
# 38        Mouse in hall 1  624.759744           9           1        hall
# 39               Enter R4  627.367898          47           4       enter
#
#                                             current
# 0   <__main__.BonsaiEvent object at 0x7fea80d36af0>
# 1   <__main__.BonsaiEvent object at 0x7fea80d36dc0>
# 2   <__main__.BonsaiEvent object at 0x7fea80e2ae80>
# 3   <__main__.BonsaiEvent object at 0x7fea8428aa00>
# 4   <__main__.BonsaiEvent object at 0x7fea8428a730>
# 5   <__main__.BonsaiEvent object at 0x7fea8428a880>
# 6   <__main__.BonsaiEvent object at 0x7fea842a99d0>
# 7   <__main__.BonsaiEvent object at 0x7fea842a9b20>
# 8   <__main__.BonsaiEvent object at 0x7fea80d5c430>
# 9   <__main__.BonsaiEvent object at 0x7fea80e0bcd0>
# 10  <__main__.BonsaiEvent object at 0x7fea842bb850>
# 11  <__main__.BonsaiEvent object at 0x7fea842bb970>
# 12  <__main__.BonsaiEvent object at 0x7fea842bba60>
# 13  <__main__.BonsaiEvent object at 0x7fea836cbc40>
# 14  <__main__.BonsaiEvent object at 0x7fea836cb8b0>
# 15  <__main__.BonsaiEvent object at 0x7fea836cb6a0>
# 16  <__main__.BonsaiEvent object at 0x7fea836cb820>
# 17  <__main__.BonsaiEvent object at 0x7fea80e1f040>
# 18  <__main__.BonsaiEvent object at 0x7fea80e1ffa0>
# 19  <__main__.BonsaiEvent object at 0x7fea80e1fd30>
# 20  <__main__.BonsaiEvent object at 0x7fea80e1f700>
# 21  <__main__.BonsaiEvent object at 0x7fea84298df0>
# 22  <__main__.BonsaiEvent object at 0x7fea84298ac0>
# 23  <__main__.BonsaiEvent object at 0x7fea84298a90>
# 24  <__main__.BonsaiEvent object at 0x7fea842ba0d0>
# 25  <__main__.BonsaiEvent object at 0x7fea842ba130>
# 26  <__main__.BonsaiEvent object at 0x7fea842baf10>
# 27  <__main__.BonsaiEvent object at 0x7fea842bae80>
# 28  <__main__.BonsaiEvent object at 0x7fea842baeb0>
# 29  <__main__.BonsaiEvent object at 0x7fea842ba460>
# 30  <__main__.BonsaiEvent object at 0x7fea842990a0>
# 31  <__main__.BonsaiEvent object at 0x7fea842993d0>
# 32  <__main__.BonsaiEvent object at 0x7fea836c1d60>
# 33  <__main__.BonsaiEvent object at 0x7fea836c12e0>
# 34  <__main__.BonsaiEvent object at 0x7fea836c1340>
# 35  <__main__.BonsaiEvent object at 0x7fea80d4a8b0>
# 36  <__main__.BonsaiEvent object at 0x7fea80d4a0d0>
# 37  <__main__.BonsaiEvent object at 0x7fea80d4ac40>
# 38  <__main__.BonsaiEvent object at 0x7fea80d4a2e0>
# 39  <__main__.BonsaiEvent object at 0x7fea80e0a040>

# %%
def get_bonsai_event_item(item):
    new_object = BonsaiEvent(item)
    return new_object

def trial_writer(events_list):
    current_restaurant = events_list.sentinel.next.restaurant
    current = events_list.sentinel.next.next
    trial = DoublyLinkedList()
    trial.add_to_end(get_bonsai_event_item(events_list.sentinel.next.item))
    trials = DoublyLinkedList()
    i = 0
    while current is not None:
        if current.restaurant == current_restaurant:
            """mouse in the same restaurant"""
            bonsai_event = get_bonsai_event_item(current.item)
            trial.add_to_end(bonsai_event)
        elif current.restaurant != current_restaurant:
            """mouse in a new restaurant"""
            trials.add_to_end(Trial(trial, i))
            trial = DoublyLinkedList()
            trial.add_to_end(get_bonsai_event_item(current.item))
            i+=1
        current_restaurant = current.restaurant
        current = current.next
    if i == 0:
        trials.add_to_end(cl.Trial(trial, i))
    return trials

trials = trial_writer(list_of_bonsaievents)
trials.sentinel.next.item.write_dataFrame()
# Out:
#        event_description   timestamp  event_code  restaurant     keyword  \
# 0  Mouse in offer zone 1  246.809690          10           1  offer zone
# 1           R1 100 offer  247.000000          20           1   100_offer
# 2               Enter R1  247.000000          11           1       enter
# 3                Quit R1  252.716992          13           1        quit
#
#                                            current
# 0  <__main__.BonsaiEvent object at 0x7fea833087c0>
# 1  <__main__.BonsaiEvent object at 0x7fea83308910>
# 2  <__main__.BonsaiEvent object at 0x7fea83308130>
# 3  <__main__.BonsaiEvent object at 0x7fea833082b0>

# %%
trials.head.restaurant = trials.head.item.head.restaurant
trials.head.restaurant
# Out:
# 1

# %%
iterator = trials.head.item.head
event_track = []
while iterator is not None:
    event_track.append(iterator.keyword)
    iterator = iterator.next
event_track
# Out:
# ['offer zone', '100_offer', 'reject', 'enter', 'quit']

# %%
def identify_direction_blocks(events):
    prev = events[0][0][-1]
    block = [events[0]]
    new_event_list = []
    for i in range(len(events[1:])):
        i_r = events[i][0][3]
        if i_r >= prev:
            prev = i_r
            block.append(events[i])
        elif prev == 4 and i_r == 1:
            prev = i_r
            block.append(events[i])
        else:
            prev = i_r
            new_event_list.append(block)
            block = [events[i]]
    return new_event_list

events_by_blocks = identify_direction_blocks(events_by_restaurants)

# %%
for i in events_by_blocks:
